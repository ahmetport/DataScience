# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Seaborn Notebook</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# ## Data Visulazation by Seaborn

# %%
#!pip install seaborn

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Seaborn içindeki data setleri

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# seabornda 3 çeşit plot tipi var
# dağılım (distribution)
# kategorik
# karşılaştırma

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# ## Scatter Plot
# Dağılım grafikleri, farklı özelliklerin birbiriyle olan ilişikisi için kullanılır.

# %% [markdown]
# ---
#
# ## Kod Açıklaması
#
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip");`
#
# Bu satırda, Seaborn kütüphanesinin `scatterplot` fonksiyonu kullanılarak bir saçılma grafiği çizilmektedir. Fonksiyonun parametreleri şunlardır:
#
# - **data = tips**: Grafik için kullanılacak veri kaynağı. Burada `tips` adlı bir DataFrame kullanılıyor.
# - **x = "total_bill"**: X ekseni için kullanılacak olan sütun, toplam fatura (total bill) olarak belirlenmiş.
# - **y = "tip"**: Y ekseni için kullanılacak olan sütun, bahşiş (tip) olarak belirlenmiş.
#
# Bu kodda, `hue` veya `style` gibi ek parametreler belirtilmemiş, bu nedenle basit bir saçılma grafiği çizilecektir.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, "total_bill" ve "tip" sütunları arasındaki ilişkiyi gösteren bir saçılma grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Her bir nokta, bir restoran müşterisini temsil eder.
#
# Bu grafik, toplam fatura miktarı ile bahşiş miktarı arasında nasıl bir ilişki olduğunu gözlemlememizi sağlar. Genel olarak, fatura miktarı arttıkça bahşiş miktarının da arttığı görülebilir, fakat her zaman böyle olmayabilir. Grafik, yalnızca genel bir eğilimi gösterir ve istisnalar da olabileceğini unutmamak gerekir.
#
# ---

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip")

plt.show()

# %% [markdown]
# ## Kod Açıklaması
#
# ### `sns.regplot(data = tips, x= "total_bill", y = "tip");`
#
# Bu satırda, Seaborn kütüphanesinin `regplot` fonksiyonu kullanılarak bir regresyon grafiği çizilir. Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri kaynağı. Burada `tips` adlı bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun, toplam hesap (total bill) olarak belirlenmiş.
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun, bahşiş (tip) olarak belirlenmiş.
#
# Bu kodda `x_estimator` parametresi belirtilmemiş, yani her bir x değeri için yatayda bir ortalaması çıkarılmayacak.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir regresyon grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Noktalar, her bir gözlemi (örneği) temsil eder ve çizilen çizgi, bu noktalar arasında en uygun fit (uyum) sağlayan doğrusal bir çizgiyi temsil eder.
#
# Bu grafik, 'total_bill' ve 'tip' arasındaki ilişkinin doğrusal olup olmadığını gözlemlemek için kullanılır.

# %% [markdown]
# ## Kod Açıklaması Ek Bilgi: Gölge Hakkında
#
# ### `sns.regplot(data = tips, x= "total_bill", y = "tip");`
#
# Bu kodda çizilen çizginin etrafındaki gölge, güven aralığını (confidence interval) temsil eder. Genellikle 95% güven aralığı olarak alınır. Yani, bu gölge, regresyon çizgisinin tahmin ettiği y değerlerinin ne kadar güvenilir olduğunu gösterir. Eğer gölge dar ise, bu modelin daha güvenilir olduğu anlamına gelir. Eğer gölge geniş ise, modelin tahminleri o kadar güvenilir değildir.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir regresyon grafiği oluşturulur. Grafiğin X ekseni 'total_bill', Y ekseni 'tip', ve çevresindeki gölge ise 95% güven aralığını temsil eder.
#
# ## Gölge Genişliği Hakkında Ek Bilgi
#
# Eğer çizginin etrafındaki gölge (güven aralığı) dar ise, bu, modelin tahminlerinin daha kesin olduğunu ve verilere daha iyi uyduğunu gösterir. Yani, yüksek olasılıkla, yeni bir gözlem (örneğin, yeni bir 'total_bill' değeri) geldiğinde, modelimizin 'tip' tahmini oldukça güvenilirdir.
#
# Eğer gölge geniş ise, bu, modelin tahminlerinin daha az kesin olduğunu ve verilere daha az iyi uyduğunu gösterir. Yani, yeni bir gözlem geldiğinde, modelimizin 'tip' tahmini daha az güvenilir olabilir.
#
# Gölge genişliği, modelin ne kadar iyi calibre edildiğinin ve verilerin ne kadar tutarlı olduğunun bir göstergesi olarak kabul edilir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Kod Açıklaması
#
# ### `sns.regplot(data = tips, x= "total_bill", y = "tip");`
#
# Bu satırda, Seaborn kütüphanesinin `regplot` fonksiyonu kullanılarak bir regresyon grafiği çizilir. Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri kaynağı. Burada `tips` adlı bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun, toplam hesap (total bill) olarak belirlenmiş.
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun, bahşiş (tip) olarak belirlenmiş.
#
# Bu kodda `x_estimator` parametresi belirtilmemiş, yani her bir x değeri için yatayda bir ortalaması çıkarılmayacak.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir regresyon grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Noktalar, her bir gözlemi (örneği) temsil eder ve çizilen çizgi, bu noktalar arasında en uygun fit (uyum) sağlayan doğrusal bir çizgiyi temsil eder.
#
# Bu grafik, 'total_bill' ve 'tip' arasındaki ilişkinin doğrusal olup olmadığını gözlemlemek için kullanılır.

# %%
sns.regplot(data = tips, x= "total_bill", y = "tip");

# %% [markdown]
# ## Figsize

# %% [markdown]
# gördüğünüz gibi burada x ve y aksislerini nasıl verdik

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = tips["total_bill"], y =tips["tip"])
plt.show()

# %% [markdown]
# ## Hue

# %% [markdown]
# Datayı bakın buarada nasıl verdik.

# %% [markdown]
# ## Kod Açıklaması
#
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker");`
#
# Bu kodda, Seaborn kütüphanesinin `scatterplot` fonksiyonu kullanılarak bir saçılım grafiği (scatter plot) çizilir. Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri seti. Burada `tips` adında bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun. Toplam hesap (total bill) olarak belirlenmiş.
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun. Bahşiş (tip) olarak belirlenmiş.
# - `hue = "smoker"`: Her bir noktanın rengini, "smoker" sütununun kategorik değerlerine göre belirler.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir saçılım grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Her bir nokta, bir gözlemi (örneği) temsil eder. Ayrıca, noktaların renkleri, kişinin sigara içip içmediğini ('smoker') gösterir. Bu şekilde, faturaların toplamı ile bahşişler arasındaki ilişkinin, sigara içme durumuna göre nasıl değiştiğini gözlemlemek mümkündür.

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker") # hue must be categorical
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day")
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex");

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day");

# %% [markdown]
# ##  Style

# %% [markdown]
# ## Kod Açıklaması
#
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex");`
#
# Bu kodda, Seaborn kütüphanesinin `scatterplot` fonksiyonu kullanılarak bir saçılım grafiği çizilmiştir. Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri seti. Burada `tips` adında bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun. Toplam hesap (total bill) olarak belirlenmiş.
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun. Bahşiş (tip) olarak belirlenmiş.
# - `style = "sex"`: Noktaların şeklini, "sex" sütununun kategorik değerlerine göre belirler.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir saçılım grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Her bir nokta, bir gözlemi (örneği) temsil eder. Noktaların şekli, cinsiyeti ("sex") gösterir, bu da gözlemlerin cinsiyetlere göre farklılıklarını gözlemlememize olanak sağlar.

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex"); # size = "smoker"

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day");

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "day");

# %% [markdown]
# ## Kod Açıklaması
#
# ### `%matplotlib notebook`
# ### `plt.figure(figsize = (10, 5))`
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "sex");`
#
# Bu kod bloğunda üç ana komponent bulunmaktadır:
#
# - `%matplotlib notebook`: Matplotlib'in notebook modunu etkinleştirir. Bu sayede dinamik grafikler oluşturulabilir.
# - `plt.figure(figsize = (10, 5))`: Çizilecek olan grafiğin boyutunu belirler.
# - `sns.scatterplot(...)`: Seaborn kütüphanesinin `scatterplot` fonksiyonu ile bir saçılım grafiği çizilir.
#
# Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Çizim için kullanılacak veri seti. `tips` DataFrame'ini kullanıyoruz.
# - `x = "total_bill"`: X ekseni için 'total_bill' sütunu kullanılır.
# - `y = "tip"`: Y ekseni için 'tip' sütunu kullanılır.
# - `style = "day"`: Noktaların şeklini belirlemek için 'day' sütunu kullanılır.
# - `hue = "sex"`: Noktaların rengini belirlemek için 'sex' sütunu kullanılır.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir saçılım grafiği elde edilir. Grafiğin X ekseni 'total_bill', Y ekseni ise 'tip' olarak belirlenmiştir. Her bir nokta bir gözlemi (örneği) temsil eder. Noktaların şekli 'day' sütununa, rengi ise 'sex' sütununa göre belirlenir. Bu sayede, farklı günlerde ve cinsiyetlere göre bahşiş miktarlarının nasıl değiştiğini gözlemlemek mümkündür.

# %%
# %matplotlib notebook
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "sex");
# Out:
# <img src="data:image/png;base64,..." width="240">

# %% [markdown]
# ## Kod Açıklaması
#
# ### `%matplotlib inline`
# ### `fig, ax = plt.subplots(1, 2, figsize =  (10, 5))`
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", ax = ax[0]);`
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker", ax = ax[1]);`
#
# Bu kod bloğunda birkaç ana komponent bulunmaktadır:
#
# - `%matplotlib inline`: Matplotlib'in inline modunu etkinleştirir. Bu, grafiklerin Jupyter Notebook içinde statik olarak görüntülenmesini sağlar.
# - `fig, ax = plt.subplots(1, 2, figsize =  (10, 5))`: 1 satır ve 2 sütundan oluşan bir subplot düzeni oluşturur ve boyutunu 10x5 olarak ayarlar.
# - İki farklı `sns.scatterplot(...)` fonksiyonu: Seaborn kütüphanesinin `scatterplot` fonksiyonunu kullanarak iki farklı saçılım grafiği çizilir.
#
# Fonksiyonların parametreleri:
#
# - `data = tips`: Çizim için kullanılacak veri seti olan `tips` DataFrame.
# - `x = "total_bill"` ve `y = "tip"`: X ve Y eksenlerinde kullanılacak sütunlar.
# - `style = "sex"`: İlk grafikte noktaların şekli cinsiyete (`sex`) göre belirlenir.
# - `hue = "smoker"`: İkinci grafikte noktaların rengi sigara içip içmeme durumuna (`smoker`) göre belirlenir.
# - `ax = ax[0]` ve `ax = ax[1]`: Hangi subplot'a çizileceği belirlenir.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, iki farklı saçılım grafiği elde edilir:
#
# 1. İlk grafik, 'total_bill' ve 'tip' arasındaki ilişkiyi cinsiyete göre gösterir. Noktaların farklı şekilleri cinsiyeti temsil eder.
# 2. İkinci grafik, 'total_bill' ve 'tip' arasındaki ilişkiyi sigara içip içmeme durumuna göre gösterir. Noktaların farklı renkleri bu durumu temsil eder.
#
# Her iki grafikte de, X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenmiştir.

# %% [markdown]
# OOM figurde axes'lerin yerini belittik.

# %%
# %matplotlib inline
fig, ax = plt.subplots(1, 2, figsize =  (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", ax = ax[0]); 
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker", ax = ax[1]);

# %% [markdown]
# # Renk

# %% [markdown]
# ## Kod Açıklaması
#
# ### `plt.figure(figsize = (10,5))`
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", palette = "plasma");`
#
# Bu kod bloğunda iki ana komponent bulunmaktadır:
#
# - `plt.figure(figsize = (10,5))`: Grafik için 10x5 boyutunda bir figür oluşturulur.
# - `sns.scatterplot(...)`: Seaborn kütüphanesinin `scatterplot` fonksiyonunu kullanarak bir saçılım grafiği çizilir.
#
# Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri seti. Burada `tips` adlı bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun, yani toplam hesap (`total_bill`).
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun, yani bahşiş (`tip`).
# - `hue = "sex"`: Noktaların rengi cinsiyete (`sex`) göre belirlenir.
# - `palette = "plasma"`: Renk paleti olarak 'plasma' seçilir. Bu, cinsiyetlere atanacak renklerin bu paletten seçileceği anlamına gelir.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir saçılım grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Noktalar, her bir gözlemi (örneği) temsil eder ve noktaların rengi cinsiyeti temsil eder. Renk paleti olarak 'plasma' kullanılmıştır, bu da renklerin daha sıcak ve göze hoş gelecek şekilde seçilmesini sağlar.

# %%
# pallette
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", palette = "plasma");

# %% [markdown]
# ## Yoğunluk

# %% [markdown]
# ## Kod Açıklaması
#
# ### `plt.figure(figsize = (10, 5))`
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", alpha = 0.3);`
#
# Bu kod bloğunda iki ana komponent bulunmaktadır:
#
# - `plt.figure(figsize = (10, 5))`: Grafik için 10x5 boyutunda bir figür oluşturulur.
# - `sns.scatterplot(...)`: Seaborn kütüphanesinin `scatterplot` fonksiyonu kullanılarak bir saçılım grafiği çizilir.
#
# Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri seti. Burada `tips` adlı bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun, yani toplam hesap (`total_bill`).
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun, yani bahşiş (`tip`).
# - `alpha = 0.3`: Noktaların şeffaflığı 0.3 olarak belirlenir. Bu, 0 ile 1 arasında bir değerdir.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir saçılım grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Noktalar, her bir gözlemi (örneği) temsil eder. Şeffaflık parametresi `alpha` sayesinde, noktaların üzerindeki yoğunluğu daha kolay anlayabiliriz. Daha şeffaf olan alanlar, daha az gözlem olduğu anlamına gelirken, daha az şeffaf olan alanlar, daha çok gözlem olduğu anlamına gelir.

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", alpha = 0.3);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day", alpha = 0.7, palette = "plasma");

# %% [markdown]
# ## S
# Grafiğin içindeki değerlerin boyutu için.

# %% [markdown]
# ## Kod Açıklaması
#
# ### `plt.figure(figsize = (10, 5))`
# ### `sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day", alpha = 0.7, s = 300);`
#
# Bu kod bloğunda iki ana komponent bulunmaktadır:
#
# - `plt.figure(figsize = (10,5))`: Grafik için 10x5 boyutunda bir figür oluşturulur.
# - `sns.scatterplot(...)`: Seaborn kütüphanesinin `scatterplot` fonksiyonu kullanarak bir saçılım grafiği çizilir.
#
# Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri seti. Burada `tips` adlı bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun, yani toplam hesap (`total_bill`).
# - `y = "tip"`: Y ekseni için kullanılacak olan sütun, yani bahşiş (`tip`).
# - `style = "sex"`: Noktaların şekli cinsiyete (`sex`) göre belirlenir.
# - `hue = "day"`: Noktaların rengi gün (`day`) değerine göre belirlenir.
# - `alpha = 0.7`: Noktaların şeffaflığı 0.7 olarak belirlenir. Bu 0 ile 1 arasında bir değerdir.
# - `s = 300`: Noktaların boyutu 300 olarak belirlenir.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, 'total_bill' ve 'tip' sütunları arasındaki ilişkiyi gösteren bir saçılım grafiği oluşturulur. Grafiğin X ekseni 'total_bill' ve Y ekseni 'tip' olarak belirlenir. Noktalar, her bir gözlemi (örneği) temsil eder. Noktaların şekli cinsiyeti temsil ederken, rengi günü temsil eder. Şeffaflık ve boyut da belirtildiği gibi ayarlanmıştır.

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day", alpha = 0.7, s = 300);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day", palette = "cubehelix");

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", size = "smoker", hue ="sex", alpha = (0.5));

# %% [markdown]
# ## Distribution Plot

# %% [markdown]
# dist plot da tekdeğişken izlenirken hist plotta birden fazla izlenebilir.
#
# ancak distplot ana dağılım grafikleri için kullanılır. Kısaca içine kind ile diğer dağlılım grafikleri eklenebilir.

# %% [markdown]
# ## Kod Açıklaması
#
# ### `sns.displot(data = tips, x = "total_bill");`
#
# Bu kodda, Seaborn kütüphanesinin `displot` fonksiyonu kullanılarak bir histogram çizilir. Bu fonksiyon, tek bir değişkenin dağılımını görselleştirmek için kullanılır. Fonksiyonun parametreleri şunlardır:
#
# - `data = tips`: Grafik için kullanılacak veri kaynağı. Burada `tips` adlı bir DataFrame kullanılıyor.
# - `x = "total_bill"`: X ekseni için kullanılacak olan sütun, toplam hesap (`total_bill`) olarak belirlenmiş.
#
# ## Output Açıklaması
#
# Bu kod bloğu çalıştırıldığında, `total_bill` sütununun dağılımını gösteren bir histogram oluşturulur. Grafiğin X ekseni 'total_bill' olarak belirlenir. Her bir çubuk, 'total_bill' değişkeninin belli bir aralığındaki gözlem sayısını temsil eder. Yüksekliği, o aralıkta kaç gözlem olduğunu gösterir.
#
# Bu grafik, `total_bill` değişkeninin dağılımını anlamak için kullanılır; örneğin, en çok hangi `total_bill` değerlerinin olduğu, dağılımın simetrik olup olmadığı gibi.

# %%
sns.displot(data = tips, x = "total_bill" );

# %%
sns.displot(tips.total_bill,  bins = 50);

# %%
sns.displot(tips.tip, kde = True, bins = 50);

# %%
fig, ax = plt.subplots(1, 2 , figsize = (10, 5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips, s = 300, hue = "sex",ax = ax[0])

sns.histplot(x = "total_bill", data = tips, ax = ax[1], kde=True);

# %%
fig, ax = plt.subplots(1, 2 , figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", s = 300, hue = "sex",ax = ax[0])

sns.histplot(data = tips, x = "total_bill", ax = ax[1], kde=True);

# %%
g = sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha=.5);
g.add_legend();

# %%
g = sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(sns.kdeplot, "total_bill", "tip", alpha=.5, shade = True);
g.add_legend();

# %% [markdown]
# FacetGrid ayrı ayrı birden çok değişken arasındaki ilişkinin yanı sıra bir değişkenin dağılımını görselleştirmeye yardımcı olur.

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist");
sns.displot(data = tips, x = "total_bill", kind = "kde");

# %% [markdown]
# aspect argümanı ile grafiği figür içinde yaty düzlemde genişletebiliriz

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist", kde = True, aspect = 1); # Kernel density estimation = kde  ekle aspect = 0

# %% [markdown]
# ## Hist plot

# %%
plt.figure(figsize = (10, 5))
sns.histplot(data = tips, x = "total_bill", bins = 150, kde = True);

# %% [markdown]
# ## Kod Açıklaması:
# Bu kod parçası, Seaborn kütüphanesini kullanarak iki farklı türde veri görselleştirmesi yapar. Birincil hedef, "total_bill" sütununu bir rugplot ile ve "tip" sütununu bir histplot ile görselleştirmektir.
#
# İlk olarak, plt.subplots(1, 2, figsize=(10, 5)) kodu, iki alt grafik (subplot) içeren bir şekil (figure) oluşturur. İlk alt grafikte "total_bill" sütununu göstereceğiz ve ikinci alt grafikte "tip" sütununu göstereceğiz. fig değişkeni, tüm şekli temsil eder ve ax değişkeni alt grafikleri temsil eder.
#
# İlk alt grafikte sns.rugplot() kullanılır. Bu, verinin dağılımını tek boyutlu bir çizgi olarak gösterir. data=tips ile veriyi belirtiriz, x="total_bill" ile hangi sütunu kullanacağımızı belirtiriz, height=0.8 ile çizginin yüksekliğini ayarlarız ve ax=ax[0] ile bu alt grafiği belirtilen konuma yerleştiririz.
#
# İkinci alt grafikte ise sns.histplot() kullanılır. Bu, verinin histogramını çizer. Yine data=tips ile veriyi belirtiriz, x="tip" ile hangi sütunu kullanacağımızı belirtiriz, kde=True ile çizgiyi (KDE - Kernel Density Estimation) ekleriz ve ax=ax[1] ile bu alt grafiği belirtilen konuma yerleştiririz.

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
sns.rugplot(data = tips, x = "total_bill", height = 0.8, ax = ax[0]);
sns.histplot(data = tips, x = "tip", kde = True, ax = ax[1]);

# %% [markdown]
# ## Çıktı Açıklaması:
# Yukarıdaki kodu çalıştırdığınızda, iki alt grafikten oluşan bir şekil (figure) görselleştirilecektir.
#
# İlk alt grafik (sol taraf): "total_bill" sütununun dağılımını gösteren bir rugplot çizimi görüntülenir. Her bir çizgi, bu sütundaki bir veri noktasını temsil eder ve bu veri noktalarının dağılımını gösterir.
#
# İkinci alt grafik (sağ taraf): "tip" sütununun histogramı ve çizgi grafiği (KDE) görüntülenir. Histogram, verilerin dağılımını sütunlar halinde gösterirken, KDE çizgisi, verilerin yoğunluğunu gösterir. Bu grafik, "tip" sütunundaki verilerin dağılımını daha iyi anlamanıza yardımcı olur.
#
# Bu kod, "total_bill" ve "tip" sütunlarındaki verilerin dağılımını görsel olarak karşılaştırmak için kullanışlı bir örnek göstermektedir.

# %% [markdown]
# ## Kod Açıklaması:
# sns.set(style="dark"): Bu kod satırı, Seaborn'un stil ayarlarını "dark" olarak ayarlar. Bu, çizimlerin daha karanlık bir arka plan üzerinde görüntülenmesini sağlar ve bir dizi varsayılan renk ve stil ayarını değiştirir.
#
# sns.histplot(data=tips, x="tip", kde=True): Bu kod satırı, "tips" adlı veri kümesindeki "tip" sütununun dağılımını görselleştirir. data=tips ile veriyi belirtiriz, x="tip" ile hangi sütunu kullanacağımızı belirtiriz ve kde=True ile histogramın üstünde sürekli yoğunluk tahmini (KDE çizgisi) ekleriz.
#
# plt.show(): Bu kod satırı, çizimi görüntüler.

# %% [markdown]
# - x ekseni: x ekseni "tip" sütunundaki verileri temsil eder. Yani, bu eksende her bir sütun, farklı bahşiş miktarlarını gösterir. Her sütun, belirli bir bahşiş aralığını temsil eder. Örneğin, bir sütun 5 ile 10 dolar arasındaki bahşişleri temsil edebilir.
#
# - y ekseni: y ekseni, belirli bir bahşiş aralığındaki veri noktalarının sayısını temsil eder. Y ekseni boyunca her bir sütunun yüksekliği, bu bahşiş aralığına sahip kaç tane veri noktasının olduğunu gösterir. Yani, her bir sütunun yüksekliği, o bahşiş aralığına ait veri noktalarının sayısını ifade eder.

# %%
sns.set(style = "dark")
sns.histplot(data = tips, x = "tip", kde = True);
plt.show()

# %% [markdown]
# ## Çıktı Açıklaması:
# Yukarıdaki kodu çalıştırdığınızda, "tip" sütunundaki verilerin dağılımını gösteren bir histogram ve bu dağılımın sürekli yoğunluk tahminini (KDE çizgisi) içeren bir grafik görüntülenecektir. Bu grafik, "tip" sütunundaki verilerin hangi aralıklarda yoğunlaştığını ve dağıldığını görsel olarak gösterir. KDE çizgisi, bu dağılımın pürüzsüz bir tahminini sunar.
#
# "sns.set(style="dark")" kodu ile arka planın karanlık olduğuna dikkat edin, bu da grafiği koyu bir temada görüntüler.

# %% [markdown]
# ## KDE Plot (kernel densty estimation)

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ## kdeplot
# bins olmadan dağılım grafigini çizgi olarak verir. Yoğunluk için.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod parçası, Seaborn kütüphanesini kullanarak "body_mass_g" sütunundaki verilerin yoğunluk tahminini (KDE - Kernel Density Estimation) görselleştirir.
#
# - x ekseni: x ekseni "body_mass_g" sütunundaki verileri temsil eder. Yani, bu eksende her bir çizgi, farklı kuşların vücut kitlelerini gösterir. x ekseni boyunca yer alan değerler, kuşların vücut kitlelerini temsil eder.
#
# - y ekseni: y ekseni, yoğunluk tahminini (KDE) temsil eder. Her bir x değeri için, y ekseni boyunca bir yoğunluk değeri bulunur. Bu değerler, verinin o belirli noktasının yoğunluğunu gösterir.

# %%
sns.kdeplot(data = penguins, x = "body_mass_g");

# %% [markdown]
# ## Çıktı açıklaması
#
# Bu kod, "body_mass_g" sütunundaki kuşların vücut kitlelerinin dağılımını gösteren bir KDE çizimi oluşturur. KDE çizgisi, verinin sürekli yoğunluğunu tahmin eder ve bu dağılımın nasıl yayıldığını gösterir. Her bir x değeri için y ekseni boyunca bir yoğunluk değeri bulunur ve bu değerler çizgi üzerinde görüntülenir. Bu grafiği kullanarak, kuşların vücut kitlelerinin dağılımını ve yoğunluğunu daha iyi anlayabilirsiniz.

# %%
sns.kdeplot(data = penguins, x = "body_mass_g", hue = "sex");

# %% [markdown]
# yüzbinde 35

# %%
sns.kdeplot(data = penguins, x = "body_mass_g", hue = "species", shade = True);

# %%
sns.kdeplot(data = penguins, x = "bill_length_mm", hue = "sex", shade = True);

# %% [markdown]
# ## 2D kde graph izohips haritası gibi

# %% [markdown]
# ## Kod açıklaması
#
# Bu kod parçası, Seaborn kütüphanesini kullanarak "total_bill" sütunu ile "tip" sütunu arasındaki ilişkiyi bir KDE (Kernel Density Estimation) çizimi ile görselleştiriyor.
# - x ekseni: x ekseni "total_bill" sütunundaki verileri temsil eder. Bu eksende her bir çizgi, farklı yemek hesaplarının toplam tutarlarını temsil eder. Her bir x değeri, bir yemek hesabının toplam tutarını ifade eder.
#
# - y ekseni: y ekseni "tip" sütunundaki verileri temsil eder. Bu eksende her bir çizgi, belirli bir bahşiş miktarını temsil eder. Her bir y değeri, bir bahşiş miktarını ifade eder.

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip");

# %% [markdown]
# ## Çıktı Açıklaması:
# Bu kodu çalıştırdığınızda, "total_bill" ve "tip" sütunları arasındaki ilişkiyi gösteren bir KDE (Kernel Density Estimation) çizimi elde edersiniz. Her bir çizgi, yemek hesaplarının toplam tutarı (x ekseni) ile bu hesaplara ait bahşiş miktarını (y ekseni) gösterir. Bu çizgi, veri noktalarının yoğunluğunu gösterir ve bu iki değişken arasındaki ilişkiyi incelemenize yardımcı olur.

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red");

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True);

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True, ax = ax[0]);
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "red", ax = ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True, ax = ax[1]);
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "blue", ax = ax[0]);

# %%
sns.displot(data = penguins,
           x = "body_mass_g",
           bins = 10,
           rug = True,
           kde = True);

# %%
fig, ax = plt.subplots(2, 2, figsize = (10, 5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "purple", shade = True, ax = ax[0][0])
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "orange", ax = ax[0][1])
sns.histplot(data = tips, x = "total_bill", color="red", ax = ax[1][0])
sns.rugplot(data = tips, x = "total_bill", height = 0.8, ax = ax[1][1]);

# %%
cars = sns.load_dataset("mpg")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %% [markdown]
# ## Kod Açıklaması
# Bu kod, cars veri setinin "weight" (ağırlık) sütununa göre bir histogram oluşturur. Histogram, araçların farklı "origin" (köken) değerleri için renklendirilmiştir (hue="origin").

# %%
sns.displot(data= cars, x ="weight", hue = "origin");

# %% [markdown]
# ## Çıktı Açıklaması
# Çıktıdaki histogram, araçların ağırlık dağılımını gösterir.
#
# X Ekseni: Araçların ağırlığı ("weight")
#
# Y Ekseni: Frekans (Her bir binin içerdiği gözlem sayısı)
#
# Renkler: Farklı kökenler (örneğin, 'USA', 'Europe', 'Japan', vb. bağlı olarak origin sütunundaki değerler neyse)
#
# Her bir renk, farklı bir kökeni temsil eder, ve bu dağılımlar üst üste bindirilmiş olarak gösterilir.
#
# Yorumlar
# Hangi ağırlık aralıklarının en yaygın olduğunu inceleyebilirsiniz.
# Farklı kökenlerden gelen araçların ağırlık dağılımları arasında anlamlı farklar olup olmadığını görmek için renkli çizgileri karşılaştırabilirsiniz.
# Belirli bir kökenin diğer kökenlere göre daha yaygın veya nadir olduğunu gözlemleyebilirsiniz.
# Bu tür bir grafik, ağırlık dağılımı ve köken arasındaki ilişkileri anlamak için yararlı olabilir. Örneğin, Avrupalı araçların genellikle daha hafif, Amerikan araçlarının ise daha ağır olup olmadığı gibi trendleri gözlemleyebilirsiniz.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod, cars adlı veri setinde cylinders sütunu 4, 6 veya 8 değerlerini alan gözlemleri seçerek bir dağılım grafiği (displot) oluşturur. Grafikler, "origin" (köken) ve "cylinders" (silindir sayısı) sütunlarına göre bir FacetGrid içerisinde düzenlenmiştir. Ayrıca, "cylinders" sütunu, farklı silindir sayılarına göre renklendirme (hue) için kullanılır.

# %%
sns.displot(data=cars[cars.cylinders.isin([4, 6, 8])], x="weight",
           col = "origin",
           row = "cylinders",
           hue ="cylinders");

# %% [markdown]
# ## Çıktı Açıklaması
# Bu çıktı bir dizi dağılım grafiği içerir, ve bu grafikler "origin" ve "cylinders" sütunlarına göre organize edilmiştir.
#
# - X Ekseni: Araçların ağırlığı ("weight")
#
# - Y Ekseni: Frekans (Her bir binin içerdiği gözlem sayısı)
#
# - Renkler: Farklı silindir sayıları (4, 6, 8)
#
# - Satırlar: Farklı silindir sayıları (4, 6, 8)
#
# - Sütunlar: Farklı kökenler (origin)
#
# Bu grafiği yorumlarken şu sorulara cevap arayabilirsiniz:
#
# - Hangi kökenli araçlar genellikle hangi ağırlıkta?
# - Farklı silindir sayılarına sahip araçların ağırlığı arasında ne gibi farklar var?
# - Aynı kökene ve silindir sayısına sahip araçların ağırlığı nasıl bir dağılım gösteriyor?
# - Her bir grafik, belirli bir köken ve silindir sayısı kombinasyonunu temsil eder. Örneğin, bir grafik Japon yapımı (örneğin origin = 'Japan') ve 4 silindirli araçların ağırlık dağılımını gösterebilir. Farklı renkler, farklı silindir sayılarını temsil eder ve bu sayede aynı grafik içerisinde farklı silindir sayılarının dağılımlarını kolayca karşılaştırabiliriz.

# %% [markdown]
# dağılım grafiklerini birlikte kullanmak veriyi tanımlamada önem arz ediyor.

# %% [markdown]
# ## Categorical Plot

# %% [markdown]
# ## Countplot

# %%
sns.countplot(data = tips, x = "day");

# %% [markdown]
# for p in ax.patches:
#     ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.5));
#
#     bu kodda p diye bir obje üretiyorum.
#
#     ax. patches ne üretiyor
#
#     Rectangle object i üretiyor 4 tane

# %% [markdown]
# ## Kod Açıklaması
# Bu kod, tips veri setinin day sütununun frekansını gösteren bir sayım grafiği (countplot) oluşturur. Her bir çubuk (patch), bir günü (Örneğin: Cuma, Cumartesi, vs.) temsil eder.
#
# Grafik oluşturulduktan sonra, her bir çubuk için yüksekliğini (frekansını) gösteren bir etiket eklenir. Bu etiketler, her bir çubuğun üzerine yerleştirilir.
#
# ax.annotate() fonksiyonu, belirtilen xy koordinatına metni eklemek için kullanılır. Bu kodda, metin (yani çubuğun yüksekliği), her çubuğun get_height() metodu ile elde edilir ve get_x() + 0.3, get_height() + 0.5 koordinatlarına yerleştirilir.

# %%
fig, ax = plt.subplots()

ax = sns.countplot(tips["day"])

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.5));
    
    # https://matplotlib.org/stable/api/patches_api.html
    # matplotlib.pyplot.annotate(text, xy, *args, **kwargs)
    # [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html]

# %% [markdown]
# ## Çıktı Açıklaması
# Çıktı bir sayım grafiği olacaktır ve her bir çubuk, tips veri setinde o gün kaç kez geçtiğini gösterir. Her bir çubuğun üzerinde, o günün kaç kez göründüğünü gösteren bir sayı olacak.
#
# - X Ekseni: Farklı günler (Örneğin: Cuma, Cumartesi, Pazar vb.)
#
# - Y Ekseni: Her bir gün için gözlem sayısı
#
# Çubukların üzerinde yer alan sayılar, o gün için kaç gözlem olduğunu belirtir. Bu sayılar, grafikte her bir çubuğun tam üzerinde yer alacaktır, bu da görsel yorum için kullanışlıdır.

# %% [markdown]
# kodu debug ediyoruz anlamaya çalışıyoruz.
# xy ler Konumunu gösteriyor
# height = değerleri veriyor
#
# p.get_height() = y düzlemindeki denk gelen yükseltideki rakamı en üste yaz
#
# p.get_x()+0.3 = yatay düzlemde yerini belirtiyor (y ekseni)
#
# p.get_height()+0.5 = dikey düzlemde yerini belirtiyor (y ekseni)

# %%
print(ax.patches)
# Out:
# <Axes.ArtistList of 4 patches>

# %% [markdown]
# ## Kod Açıklaması
# Bu kod, bir Seaborn veya Matplotlib grafikte yer alan çubuklar veya yamalar (patches) hakkında bilgi almak için bir for döngüsü kullanır. Döngü, grafikte yer alan her bir çubuğu (patch) tek tek döner ve print(p) komutu ile bu çubukların özelliklerini konsola yazdırır.

# %%
for p in ax.patches:
    print(p)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=62, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=19, angle=0)
# Rectangle(xy=(1.6, 0), width=0.8, height=87, angle=0)
# Rectangle(xy=(2.6, 0), width=0.8, height=76, angle=0)

# %% [markdown]
# ## Çıktı Açıklaması
# Çıktı, her bir çubuk için geometrik özellikler ve yerleşim hakkında bilgiler içerir. Örneğin, Rectangle nesnesi ile başlayan bir çıktı görülebilir ve bu, her bir çubuğun x ve y koordinatlarını, genişliğini ve yüksekliğini gösterir.
#
# Bu bilgiler, çubukların boyutları veya koordinatları hakkında daha detaylı bilgi almak için kullanılabilir. Özellikle, grafikteki etiketler veya metinler için konum belirlemek istediğinizde bu bilgiler faydalı olabilir.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod, tips veri seti üzerinde bir sayım grafiği (countplot) çizmek için Seaborn kütüphanesini kullanır.
#
# - fig, ax_tip = plt.subplots(figsize = (10,5)): 10x5 boyutlarında bir grafik oluşturur.
# - sns.countplot(data = tips, x = "day", hue = "sex"): X ekseni için "day" (gün) değişkenini ve "hue" parametresi için "sex" (cinsiyet) değişkenini kullanır.
# - for p in ax_tip.patches:: Grafikte yer alan her bir çubuk için yüksekliğini grafiğe ekler.

# %%
# addition hue
fig, ax_tip = plt.subplots(figsize = (10,5))

ax_tip = sns.countplot(data = tips, x = "day",  hue = "sex");

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+0.15, p.get_height()+1));

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Haftanın günleri ("day").
# - Y ekseni: Her bir gün için toplam kayıt sayısı.
#
# ### Efsane ve Yorumlama
# - Efsane (Legend): Cinsiyet değişkenini temsil eden renkleri gösterir.
# - Bu grafik, farklı günlerde ve farklı cinsiyetler için bahşiş bırakma sayısını gösterir. Yani, haftanın belirli günlerinde hangi cinsiyetin daha fazla veya daha az bahşiş bıraktığını anlamak için bu grafik kullanılabilir.
#
# - Her bir çubuk üstündeki sayı, o gün ve o cinsiyet için toplam bahşiş sayısını temsil eder. Örneğin, Cumartesi günü erkeklerden gelen bahşiş sayısını, erkekler için Cumartesi gününe karşılık gelen çubuğun yüksekliğinden okuyabilirsiniz.
#
# - Bu sayede, hangi günlerin en yoğun olduğunu ve hangi cinsiyetin daha fazla bahşiş bıraktığına dair bir fikir edinebiliriz.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti kullanılarak bir sayım grafiği (countplot) oluşturur. Grafiği çizen kod, matplotlib ve seaborn kütüphanelerini kullanır.
#
# - fig, ax = plt.subplots(figsize=(12,6)): 12x6 boyutlarında bir grafik çerçevesi oluşturur.
# - sns.countplot(x='day', data=tips, hue="sex"): 'day' (gün) değişkenini x ekseni olarak, cinsiyeti (sex) ise farklı renklerle göstermek üzere seçer.
# - ax.annotate(): Her bir çubuğun üstüne, çubuğun yüksekliğini (yani kaç veri noktası olduğunu) yazdırır.
# - ax.text(): Yüzde etiketini ekler, bu etiket her bir çubuğun temsil ettiği veri noktalarının toplam veri noktasına oranını gösterir.
# - plt.legend(loc="upper left"): Efsaneyi grafiğin sol üst köşesine yerleştirir.

# %%
fig, ax = plt.subplots(figsize= (12,6))

ax = sns.countplot(x='day', data=tips, hue="sex")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.15, p.get_height()+1))
    ax.text(p.get_x()+0.07, p.get_height()-4,"%"+str(round(p.get_height()/tips.day.count()*100, 2))) # yüzdelik ekledik

plt.legend(loc="upper left");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Haftanın günleri ("day")
# - Y ekseni: Her bir gün için toplam kayıt sayısı
#
# ### Legend ve Yorumlama
# - Legend: Farklı cinsiyetler için kullanılan renkleri gösterir.
# - Bu grafik, farklı günlerde hangi cinsiyetten kaç kişinin bahşiş bıraktığını gösterir. Yani, haftanın hangi günlerinde erkeklerin mi, yoksa kadınların mı daha fazla bahşiş bıraktığını görebilirsiniz.
#
# #### Her bir çubuk üzerinde iki farklı bilgi bulunmaktadır:
#
# - Çubuğun tepesindeki sayı, o gün ve o cinsiyet için toplam kayıt sayısını gösterir.
# - Çubuğun hemen altındaki yüzdelik değer, toplam kayıt sayısına göre o çubuğun temsil ettiği oranı gösterir.
# - Bu yüzden, grafiği okurken hem sayıları hem de yüzdelik değerleri dikkate alarak daha kapsamlı bir yorum yapabilirsiniz.

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(x = "cylinders", data = mpg );

# %%
sns.countplot(data=mpg, x='model_year' );

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, mpg (miles per gallon) veri seti üzerinde bir countplot (sayım grafiği) oluşturur. Grafik, farklı model yıllarına ("model_year") göre araçların kökenini ("origin") gösterir.
#
# - figsize=(10,5): Grafik boyutunu belirler.
# - style="whitegrid": Arka plana bir ızgara ekler.
# - hue="origin": Köken (origin) özelliği için farklı renkler kullanır.
# - legend(loc="upper center"): Efsaneyi (legend) grafiğin üst orta kısmına yerleştirir.

# %%
plt.figure(figsize = (10,5))

sns.set(style= "whitegrid")

sns.countplot(x ="model_year", hue = "origin", data = mpg);

plt.legend(loc="upper center");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Araç model yılları ("model_year")
# - Y ekseni: Araç sayısı
#
# ### Efsane ve Yorumlama
# - Efsane (Legend): Farklı kökenler (origin) için kullanılan renkleri gösterir.
# - Bu grafik, farklı model yıllarında üretilen araçların kökenine göre dağılımını gösterir. Örneğin, 1970 model yılı için Amerika'dan kaç araç, Avrupa'dan kaç araç ve Asya'dan kaç araç olduğunu görebilirsiniz. Efsane, hangi renk kodunun hangi kökeni temsil ettiğini belirtir.
#
# - Bu tür bir grafik, model yılına göre araçların kökeninin nasıl değiştiğini görmek için oldukça faydalıdır. Efsaneyi grafiğin üst orta kısmına yerleştirmek, kökenleri kolaylıkla ayırt etmeyi sağlar.

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti üzerinde bir barplot (çubuk grafik) oluşturur. Grafikte, cinsiyete ("sex") göre ortalama bahşiş ("tip") miktarlarını gösterir.
#
# - Varsayılan estimator fonksiyonu np.mean olduğundan, bu grafik her bir cinsiyet için ortalama bahşiş miktarını gösterir. Hata çubukları da konfidans aralığını (confidence interval) gösterir.

# %% [markdown]
# confidance interval =ci güven aralığı ( dikey çizgiler )
#
# Standart sapma, bir sayının bir serideki ortalama sayıdan farklılık gösteren miktarın istatistiksel ölçümüdür. Düşük standart sapma, verilerin ortalamayla çok yakından ilişkili olduğu ve dolayısıyla çok güvenilir olduğu anlamına gelir. Yüksek bir standart sapma, veriler ile istatistiksel ortalama arasında büyük bir fark olduğu ve o kadar güvenilir olmadığı anlamına gelir.
#
# En üst değerler cinsiyete göre ortalama bahşiş durumu

# %%
sns.barplot(data = tips,  x="sex", y="tip");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Cinsiyet ("sex")
# - Y ekseni: Ortalama bahşiş miktarı ("tip")
#
# ### Hata Çubukları ve Yorumlama
# - Her bir çubuk, belirli bir cinsiyet için ortalama bahşiş miktarını temsil eder.
# - Hata çubukları (üstteki küçük çizgiler) belirli bir konfidans düzeyinde ortalama bahşiş miktarının beklenen aralığını gösterir.
# - Kısa Hata Çubukları: Ortalama değer etrafında küçük bir belirsizlik olduğu anlamına gelir.
# - Uzun Hata Çubukları: Ortalama değer etrafında büyük bir belirsizlik olduğu anlamına gelir.
# - Bu grafik, cinsiyete göre ortalama bahşiş miktarlarını karşılaştırmak için kullanılabilir. Ayrıca, hata çubukları sayesinde, bu ortalama değerlerin ne kadar güvenilir olduğunu da değerlendirebiliriz.

# %% [markdown]
# cinsiyete göre verilen toplam bahşişi gösterelim
#
# burada düz çizgiler Cİ(confidance interval)

# %% [markdown]
# ![CI.jpg](attachment:CI.jpg)

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti üzerinde bir barplot (çubuk grafik) oluşturur. Grafikte, cinsiyete ("sex") göre toplam bahşiş ("tip") miktarlarını gösterir.
#
# - estimator=np.sum: Toplam bahşiş miktarını hesaplamak için kullanılır.
# - Hata çubukları: Default olarak konfidans aralığını (confidence interval) gösterir.

# %%
# add sum() estimator
sns.barplot("sex", "tip", data = tips, estimator= np.sum);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Cinsiyet ("sex")
# - Y ekseni: Toplam bahşiş miktarı ("tip")
#
# ### Hata Çubukları ve Yorumlama
# - Her bir çubuk, belirli bir cinsiyet için toplam bahşiş miktarını temsil eder.
# - Hata çubukları (üstteki küçük çizgiler) belirli bir konfidans düzeyinde toplam bahşiş miktarının beklenen aralığını gösterir.
# - Kısa Hata Çubukları: Toplam değer etrafında küçük bir belirsizlik olduğu anlamına gelir.
# - Uzun Hata Çubukları: Toplam değer etrafında büyük bir belirsizlik olduğu anlamına gelir.
# - Bu grafik, cinsiyete göre toplam bahşiş miktarlarını karşılaştırmak için kullanılabilir. Ayrıca, hata çubukları sayesinde, bu toplam değerlerin ne kadar güvenilir olduğunu da değerlendirebiliriz.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti üzerinde bir barplot (çubuk grafik) oluşturur. Grafikte, cinsiyete ("sex") göre minimum bahşiş ("tip") miktarlarını gösterir.
#
# - estimator=np.min: Minimum bahşiş miktarını hesaplamak için kullanılır.
# - Hata çubukları: Default olarak konfidans aralığını (confidence interval) gösterir.

# %%
# add min() estimator
sns.barplot("sex", "tip", data = tips, estimator= np.min);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Cinsiyet ("sex")
# - Y ekseni: Minimum bahşiş miktarı ("tip")
#
# ### Hata Çubukları ve Yorumlama
# - Her bir çubuk, belirli bir cinsiyet için minimum bahşiş miktarını temsil eder.
# - Hata çubukları (üstteki küçük çizgiler) belirli bir konfidans düzeyinde minimum bahşiş miktarının beklenen aralığını gösterir.
# - Kısa Hata Çubukları: Minimum değer etrafında küçük bir belirsizlik olduğu anlamına gelir.
# - Uzun Hata Çubukları: Minimum değer etrafında büyük bir belirsizlik olduğu anlamına gelir.
# - Bu grafik, cinsiyete göre minimum bahşiş miktarlarını karşılaştırmak için kullanılabilir. Ancak, hata çubuklarının varlığı, minimum değerler için standart bir belirsizlik ölçüsü sağlar; bu, birçok farklı değer arasında minimumun nasıl değişebileceğini gösterir.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti üzerinde bir barplot (çubuk grafik) oluşturur. Grafikte, cinsiyete ("sex") göre ortalama bahşiş ("tip") miktarlarını gösterir.
#
# - estimator=np.mean: Ortalama bahşiş miktarını hesaplamak için kullanılır.
# - Hata çubukları: Default olarak konfidans aralığını (confidence interval) gösterir.

# %%
# add mean() estimator
sns.barplot("sex", "tip", data = tips, estimator= np.mean);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Cinsiyet ("sex")
# - Y ekseni: Ortalama bahşiş miktarı ("tip")
#
# ### Hata Çubukları ve Yorumlama
# - Her bir çubuk, belirli bir cinsiyet için ortalama bahşiş miktarını temsil eder.
# - Hata çubukları (üstteki küçük çizgiler) belirli bir konfidans düzeyinde ortalama bahşiş miktarının beklenen aralığını gösterir.
# - Kısa Hata Çubukları: Ortalama değer etrafında küçük bir belirsizlik olduğu anlamına gelir.
# - Uzun Hata Çubukları: Ortalama değer etrafında büyük bir belirsizlik olduğu anlamına gelir.
# - Bu grafik, cinsiyete göre ortalama bahşiş miktarlarını karşılaştırmak için kullanılabilir. Ayrıca, hata çubukları sayesinde, bu ortalama değerlerin ne kadar güvenilir olduğunu da değerlendirebiliriz.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti üzerinde bir barplot (çubuk grafik) oluşturur. Grafikte, cinsiyete ("sex") göre ortalama bahşiş ("tip") miktarlarını gösterir.
#
# - estimator=np.mean: Ortalama bahşiş miktarını hesaplamak için kullanılır.
# - ci="sd": Hata çubukları için standart sapmayı kullanır, yani ne kadar değişkenlik olduğunu gösterir.

# %%
# add sd() ci()
sns.barplot("sex", "tip", data = tips, estimator= np.mean, ci = "sd");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Cinsiyet ("sex")
# - Y ekseni: Ortalama bahşiş miktarı ("tip")
#
# ### Hata Çubukları ve Yorumlama
# - Her bir çubuk, belirli bir cinsiyet için ortalama bahşiş miktarını temsil eder.
# - Hata çubukları (üstteki küçük çizgiler) bahşiş miktarının standart sapmasını gösterir.
# - Kısa Hata Çubukları: Bahşiş miktarları oldukça tutarlı.
# - Uzun Hata Çubukları: Bahşiş miktarları oldukça değişken.
# - Bu grafik, cinsiyete göre ortalama bahşiş miktarlarını karşılaştırmak için kullanılabilir. Ayrıca, hata çubukları sayesinde, bu ortalama değerlerin ne kadar güvenilir olduğunu da değerlendirebiliriz.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri seti üzerinde bir barplot (çubuk grafik) oluşturur. Grafikte, cinsiyete ("sex") göre ortalama bahşiş ("tip") miktarlarını görmek mümkündür. Ayrıca, "smoker" (sigara içen) özelliğine göre farklı renklerle gösterilmektedir.
#
# - estimator=np.mean: Ortalama bahşiş miktarını hesaplamak için kullanılır.
# - ci="sd": Hata çubukları için standart sapmayı kullanır.
#
# - **Not:** Barların üzerindeki çizgiler, hata çubukları olarak bilinir ve genellikle bir değerin belirsizliğini gösterir. Bu örnekte, hata çubukları standart sapmayı (ci="sd") temsil ediyor, yani bahşiş miktarlarının ne kadar değişken olduğunu gösteriyor.
#
# **Ne Anlama Geliyor?**
# - Kısa Hata Çubukları: Bahşiş miktarlarının oldukça tutarlı olduğu ve ortalamanın etrafında sıkı bir şekilde toplandığı anlamına gelir. Yani, bu grubun bahşiş miktarları genellikle birbirine yakındır.
#
# - Uzun Hata Çubukları: Bahşiş miktarlarının oldukça değişken olduğu ve ortalamanın etrafında geniş bir aralıkta dağıldığı anlamına gelir. Yani, bu grubun bahşiş miktarları birbirinden oldukça farklıdır.
#
# - Hata çubuklarını yorumlarken, ortalama değerler arasındaki farkın ne kadar "gerçek" olduğunu daha iyi anlamak için de kullanabiliriz. Örneğin, iki grubun ortalamaları arasında bir fark varsa ama hata çubukları çakışıyorsa, bu farkın istatistiksel olarak anlamlı olmayabileceğini düşünebiliriz.

# %%
sns.barplot("sex", "tip", data = tips, estimator= np.mean, ci = "sd", hue = "smoker");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Cinsiyet ("sex")
# - Y ekseni: Ortalama bahşiş miktarı ("tip")
#
# #### Yorumlama
# - Her bir çubuk, belirli bir cinsiyet için ortalama bahşiş miktarını temsil eder.
# - Hata çubukları (üstte ve altta küçük çizgiler), bahşiş miktarının standart sapmasını gösterir.
# - Farklı renkler, bahşiş veren kişinin sigara içip içmediğini ("smoker") gösterir.
# - Bu grafik, cinsiyete ve sigara içme durumuna göre ortalama bahşiş miktarlarını karşılaştırmak için kullanılabilir. Örneğin, erkeklerin mi yoksa kadınların mı daha fazla bahşiş verdiğini, sigara içenlerin mi yoksa içmeyenlerin mi daha fazla bahşiş verdiğini görmek için bu grafik kullanılabilir.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri setinde farklı günlerde kaç kayıt olduğunu göstermek için bir countplot oluşturuyor. Ayrıca, her bir çubuğun üzerine etiket olarak çubuğun yüksekliği (gözlem sayısı) ve bu yüksekliğin tüm günler arasında kapladığı yüzdelik oranı ekleniyor.
#
# - **for p in ax_tip.patches:** döngüsü ile her bir çubuk (patch) için etiket oluşturuluyor. Bu etiketler çubukların üzerinde gösteriliyor.

# %%
fig, ax_tip = plt.subplots()
ax_tip = sns.countplot(x = "day", data = tips);

for p in ax_tip.patches:
    ax_tip.annotate("(" +
                   str(p.get_height()) +
                   ")" +
                   "%" +
                   str(round((p.get_height()) / tips.day.count(), 2) * 100), (p.get_x() + 0.07, p.get_height() - 10));

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# - X ekseni: Günler ("day")
# - Y ekseni: Her bir gün için gözlem sayısı
#
# #### Yorumlama
# - Çubuklar, veri setinde belirli bir gün için kaç gözlem olduğunu gösterir.
# - Çubukların yüksekliği, o gün için veri setinde kaç kayıt olduğunu yansıtır.
# - Çubukların üzerindeki etiketler, iki bilgi parçası içerir:
# - Çubuğun yüksekliği (yani, gözlem sayısı)
# - Bu gözlem sayısının tüm günler arasında kapladığı yüzdelik oran
# - Bu grafik, hangi günlerin daha yoğun olduğu veya daha az yoğun olduğu hakkında ayrıntılı bilgi sağlar. Özellikle etiketler, gözlem sayılarının tüm veri seti içinde ne kadar önemli olduğunu yüzdelik olarak gösterir. Yani, belirli bir günün diğer günlerle karşılaştırıldığında ne kadar yoğun olduğunu daha iyi anlamamızı sağlar.

# %% [markdown]
# ## Bar and Count Plots

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, plt.subplots fonksiyonu ile bir satır ve iki sütundan oluşan bir subplot düzeni oluşturuyor. İki farklı grafik çiziliyor:
#
# - **İlk grafik (ax[0]),** tips veri seti üzerinden "day" (Gün) ve "total_bill" (Toplam Hesap) değişkenleri için bir barplot (çubuk grafik) oluşturuyor.
# - **İkinci grafik (ax[1]),** tips veri setinde farklı günlerde kaç kayıt olduğunu gösteren bir countplot (sayım grafiği) oluşturuyor.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 6))

ax[0] = sns.barplot(data = tips, x = "day", y = "total_bill", ax = ax[0])
ax[1] = sns.countplot(data = tips, x = "day", ax = ax[1]);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
# **İlk grafik (ax[0]):**
#
# - X ekseni: Günler ("day")
# - Y ekseni: Toplam hesap ("total_bill") miktarlarının ortalaması
#
# **İkinci grafik (ax[1]):**
# - X ekseni: Günler ("day")
# - Y ekseni: Her bir gün için gözlem sayısı
#
# #### Yorumlama
# **İlk Grafik: Barplot**
#
# - Her çubuk, belirli bir gün için toplam hesap miktarının ortalamasını gösterir.
# - Çubukların yüksekliği, o gün için ortalama toplam hesap miktarını yansıtır.
#
# **İkinci Grafik: Countplot**
#
# - Her çubuk, belirli bir gün için veri setinde kaç gözlem olduğunu gösterir.
# - Çubukların yüksekliği, o gün için veri setinde kaç kayıt olduğunu yansıtır.
# - Bu iki grafik, farklı günlerde toplam hesap miktarları ve sipariş sayılarının nasıl değiştiğini anlamak için yararlıdır. İki grafik de farklı yönlerden aynı hikayeyi anlatır; yani hangi günlerin iş yaptığı konusunda bilgi sağlar. Örneğin, bir gün için barplot'ta çubuk yüksek ve countplot'ta çubuk da yüksekse, bu genellikle o gün çok sayıda ve yüksek tutarlı işlemler yapıldığı anlamına gelebilir.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, iki yan yana subplot oluşturuyor. Her bir subplot farklı bir grafik tipini gösterir:
#
# - İlk grafik (ax[0]), tips veri seti üzerinden "day" (Gün) ve "total_bill" (Toplam Hesap) değişkenleri için bir barplot (çubuk grafik) oluşturuyor. Ortanca (np.median) değeri çubukların yüksekliğini belirlemek için kullanılır.
# - İkinci grafik (ax[1]), tips veri setinde farklı günlerde kaç kayıt olduğunu gösteren bir countplot (sayım grafiği) oluşturuyor.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 6))

ax[0] = sns.barplot(data = tips, x = "day", y = "total_bill", ax = ax[0], estimator= np.median)
ax[1] = sns.countplot(data = tips, x = "day", ax = ax[1]);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Eksenler ve Genel Bakış
#
# **İlk grafik (ax[0]):**
# - X ekseni: Günler ("day")
# - Y ekseni: Toplam hesap ("total_bill") miktarları
#
# **İkinci grafik (ax[1]):**
# - X ekseni: Günler ("day")
# - Y ekseni: Her bir gün için gözlem sayısı
#
# #### Yorumlama
# **İlk Grafik: Barplot**
# - Her çubuk, belirli bir gün için toplam hesap miktarının ortancasını gösterir.
# - Çubukların yüksekliği, o günün ortanca toplam hesap miktarını yansıtır.
#
# **İkinci Grafik: Countplot**
# - Her çubuk, belirli bir gün için veri setinde kaç gözlem olduğunu gösterir.
# - Çubukların yüksekliği, o gün için veri setinde kaç kayıt olduğunu yansıtır.
# - Bu iki grafik, farklı günlerde toplam hesap miktarlarının ve sipariş sayılarının nasıl değiştiğini anlamak için yararlıdır. Örneğin, eğer bir gün için barplot'ta çubuk yüksek ve countplot'ta çubuk düşükse, bu genellikle o gün az sayıda, fakat yüksek tutarlı işlemler yapıldığı anlamına gelebilir.

# %% [markdown]
# ## Box Plot

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Seaborn kütüphanesini kullanarak tips veri seti üzerinde "day" (Gün) ve "tip" (Bahşiş) değişkenleri için dikey bir boxplot (kutu grafiği) oluşturuyoruz.
#
# - x = "day", y = "tip", data = tips: X ekseni için "day" (Gün), Y ekseni için "tip" (Bahşiş) değişkenlerini ve veri seti olarak tips'i kullanıyoruz.

# %%
# Outlies values of Saturday
sns.boxplot(x = "day", y = "tip", data = tips);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda dört dikey boxplot göreceksiniz, her biri bir günü (Pazartesi, Salı, vb.) temsil eder.
#
# #### Eksenler
# - X ekseni: Günler ("day") yer alır.
# - Y ekseni: Bahşiş miktarları ("tip") yer alır.
#
# #### Yorumlama
# - Her kutu, farklı günler için bahşiş miktarlarının kuartil dağılımını gösterir.
# - Kutunun alt çizgisi: İlk kuartil (Q1) değerini temsil eder.
# - Kutunun üst çizgisi: Üçüncü kuartil (Q3) değerini temsil eder.
# - Kutunun içindeki çizgi: Medyan değeri temsil eder.
# - Whisker'lar (kutunun üstünden ve altından çıkan çizgiler), değerlerin ne kadar yayıldığını gösterir.
# - Outlier'lar (aykırı değerler), kutunun dışında tekil noktalar olarak gösterilir. Özellikle Cumartesi günü için gözlemlenen aykırı değerler var.
# - Cumartesi günü için gözlemlenen outlier'lar, bu günde özellikle yüksek veya düşük bahşişlerin verildiği anlamına gelebilir. Bu tür outlier'lar genellikle daha derin bir analiz gerektirir.

# %% [markdown]
# ![box%20plot.png](attachment:box%20plot.png)

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Seaborn kütüphanesini kullanarak tips veri setinden "day" (Gün) ve "total_bill" (Toplam Hesap) değişkenleri için dikey bir boxplot (kutu grafiği) oluşturuyoruz.
#
# - x = "day", y = "total_bill", data = tips: x ekseni için "day" (Gün), y ekseni için "total_bill" (Toplam Hesap) değişkenlerini ve veri seti olarak tips'i kullanıyoruz.

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda dört dikey boxplot göreceksiniz, her biri bir günü (Pazartesi, Salı, vb.) temsil eder.
#
# #### Eksenler
# - X ekseni: Günler ("day") yer alır.
# - Y ekseni: Toplam hesap ("total_bill") miktarları yer alır.
#
# #### Yorumlama
# - Kutular, farklı günler için toplam hesap miktarlarının kuartil dağılımını gösterir.
# - Kutunun alt çizgisi: İlk kuartil (Q1) değerini temsil eder.
# - Kutunun üst çizgisi: Üçüncü kuartil (Q3) değerini temsil eder.
# - Kutunun içindeki çizgi: Medyan değeri temsil eder.
# - Whisker'lar (kutunun üstünden ve altından çıkan çizgiler), değerlerin ne kadar yayıldığını gösterir.
# - Outlier'lar (aykırı değerler), kutunun dışında tekil noktalar olarak gösterilir.
#
# Bu grafik, farklı günler için toplam hesap miktarlarının ne kadar değiştiğini görmek için yararlıdır. Eğer bir günün kutusu diğerlerinden daha yükseğe yerleşmişse, o gün daha yüksek hesaplar ödendiği anlamına gelebilir.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Seaborn kütüphanesi kullanılarak tips veri seti için dikey bir boxplot (kutu grafiği) oluşturuluyor.
#
# - x = "day", y = "total_bill", data = tips: x ekseni için "day" (Gün), y ekseni için "total_bill" (Toplam Hesap) ve veri seti olarak tips seçilir.
# - hue = "sex": Renk tonu (hue) için "sex" (Cinsiyet) değişkeni seçilir.

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips, hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda dikey bir boxplot göreceksiniz. Bu plot, "day" ve "total_bill" değişkenlerinin nasıl bir dağılım gösterdiğini, ayrıca "sex" (Cinsiyet) değişkeni ile nasıl bir ilişkisi olduğunu göstermektedir.
#
# #### Renkler ve Boyutlar
# - Kutular, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
#
# #### Eksenler
# - x ekseninde "day" (Gün), y ekseninde ise "total_bill" (Toplam Hesap) değişkenleri yer alır.
#
# #### Yorumlama
# - Boxplot, toplam hesap miktarlarının gün ve cinsiyet boyunca nasıl değiştiğini gösterir.
# - X ekseni hangi gün olduğunu, y ekseni ise toplam hesap miktarını temsil eder.
# - Her bir kutu, ilgili gün ve cinsiyet için toplam hesap miktarlarının kuartil dağılımını gösterir:
# - Kutunun alt çizgisi, ilk kuartil (Q1) değerini
# - Kutunun üst çizgisi, üçüncü kuartil (Q3) değerini
# - Kutunun içindeki çizgi, medyan değeri temsil eder.
# - Bu grafik, farklı günler ve cinsiyetler için toplam hesap miktarlarının nasıl değiştiğini görmek için oldukça yararlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Seaborn kütüphanesi kullanılarak tips veri seti için dikey bir boxplot (kutu grafiği) oluşturuluyor.
#
# - x = "day", y = "total_bill", data = tips: x ekseni için "day" (Gün), y ekseni için "total_bill" (Toplam Hesap) ve veri seti olarak tips seçilir.
# - hue = "smoker": Renk tonu (hue) için "smoker" (Sigara İçen) değişkeni seçilir.

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips, hue = "smoker");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda dikey bir boxplot göreceksiniz. Bu plot, "day" ve "total_bill" değişkenlerinin nasıl bir dağılım gösterdiğini, ayrıca "smoker" (Sigara İçen) değişkeni ile nasıl bir ilişkisi olduğunu göstermektedir.
#
# #### Renkler ve Boyutlar
# Kutular, "smoker" (Sigara İçen) değişkenine göre renk kodlanmıştır.
#
# #### Eksenler
# x ekseninde "day" (Gün), y ekseninde ise "total_bill" (Toplam Hesap) değişkenleri yer alır.
#
# #### Yorumlama
# - Boxplot, toplam hesap miktarlarının gün ve sigara içen/sigara içmeyen durumu boyunca nasıl değiştiğini gösterir.
# - X ekseni hangi gün olduğunu, y ekseni ise toplam hesap miktarını temsil eder.
# - Her bir kutu, ilgili gün ve sigara içme durumu için toplam hesap miktarlarının kuartil dağılımını gösterir:
# - Kutunun alt çizgisi, ilk kuartil (Q1) değerini
# - Kutunun üst çizgisi, üçüncü kuartil (Q3) değerini
# - Kutunun içindeki çizgi, medyan değeri temsil eder.
# - Bu grafik, farklı günler ve sigara içme durumları için toplam hesap miktarlarının nasıl değiştiğini görmek için yararlıdır.

# %% [markdown]
# posisyonel argüman

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri seti için yatay bir boxplot (kutu grafiği) oluşturulmaktadır.
#
# - plt.figure(figsize = (10,5)): Grafiğin boyutları 10x5 olarak belirlenir.
# - x = "tip", y = "day", data = tips: x ekseni için "tip" (Bahşiş), y ekseni için "day" (Gün) ve veri seti olarak tips kullanılır.
# - hue = "sex": Renk tonu (hue) için "sex" (Cinsiyet) değişkeni seçilir.

# %%
# horizontal box plot
plt.figure(figsize = (10,5))
sns.boxplot(x = "tip", y = "day", data = tips, hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir boxplot göreceksiniz. Bu plot, verilerin x ekseni ("tip") ve y ekseni ("day") boyunca nasıl dağıldığını gösterir.
#
# #### Renkler ve Boyutlar
# - Boxplotlar, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
#
# #### Eksenler
# - x ekseninde "tip" (Bahşiş), y ekseninde ise "day" (Gün) değişkenleri yer almaktadır.
#
# #### Yorumlama
# - Boxplot, bahşiş miktarlarının gün ve cinsiyet boyunca nasıl değiştiğini gösterir.
# - X ekseni bahşiş miktarını, y ekseni ise hangi gün olduğunu temsil eder.
# - Her bir kutu, ilgili gün ve cinsiyet için bahşiş miktarlarının kuartil dağılımını gösterir:
# - Kutunun alt çizgisi, ilk kuartil (Q1) değerini
# - Kutunun üst çizgisi, üçüncü kuartil (Q3) değerini
# - Kutunun içindeki çizgi, medyan değeri temsil eder.
# - Bu grafik, farklı günler ve cinsiyetler için bahşiş miktarlarının nasıl değiştiğini görmek için oldukça kullanışlıdır.

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri seti için yatay bir violinplot (keman grafiği) oluşturuluyor.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - x = "day", y = "tip", data = tips: x ekseni için "day" (Gün), y ekseni için "tip" (Bahşiş) ve veri seti olarak tips seçilir.

# %%
plt.figure(figsize = (12, 6))

sns.violinplot(x = "day", y = "tip", data = tips);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir violinplot göreceksiniz. Bu plot, verilerin x ekseni boyunca ("day") ve y ekseni boyunca ("tip") nasıl dağıldığını gösterir.
#
# #### Eksenler
# - x ekseninde "day" (Gün), y ekseninde ise "tip" (Bahşiş) değişkenleri yer alır.
#
# #### Yorumlama
# - Violinplot, bahşiş verilerinin gün boyunca nasıl dağıldığını gösterir.
# - X ekseni, hangi gün olduğunu; y ekseni ise bahşiş miktarını temsil eder.
# - Keman grafiklerinin genişliği, o gün için bahşiş miktarının sıklığını gösterir.
# - Bu grafik, "day" gibi kategorik bir değişken ile "tip" gibi bir sürekli değişkenin nasıl bir ilişkiye sahip olduğunu görmek için yararlıdır. Cinsiyet gibi bir renk tonu olmadığı için, grafik yalnızca günler arası bahşiş dağılımını göstermektedir.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri seti için yatay bir violinplot (keman grafiği) oluşturuluyor.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - x = "day", y = "tip", data = tips: x ekseni için "day" (Gün), y ekseni için "tip" (Bahşiş) ve veri seti olarak tips seçilir.
# - hue = "sex": Renk tonu (hue) için "sex" (Cinsiyet) değişkeni seçilir.

# %%
plt.figure(figsize = (12, 6))

sns.violinplot(x = "day", y = "tip", data = tips, hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir violinplot göreceksiniz. Bu plot, verilerin x ekseni boyunca ("day") ve y ekseni boyunca ("tip") nasıl dağıldığını gösterir.
#
# #### Renkler ve Boyutlar
# - Keman grafikleri, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
#
# #### Eksenler
# - x ekseninde "day" (Gün), y ekseninde ise "tip" (Bahşiş) değişkenleri yer alır.
#
# #### Yorumlama
# - Violinplot, bahşiş verilerinin gün ve cinsiyet boyunca nasıl dağıldığını gösterir.
# - X ekseni, hangi gün olduğunu; y ekseni ise bahşiş miktarını temsil eder.
# - Keman grafiklerinin genişliği, o gün ve cinsiyet için bahşiş miktarının sıklığını gösterir.
# - Bu grafik, "day" ve "sex" gibi kategorik değişkenlerle "tip" gibi bir sürekli değişkenin ilişkisini gözlemlemek için oldukça kullanışlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri seti için bir violinplot (keman grafiği) oluşturuluyor.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - y = "day", x = "tip", data = tips: y ekseni için "day" (Gün), x ekseni için "tip" (Bahşiş) ve veri seti olarak tips seçilir.
# - hue = "sex": Renk tonu (hue) için "sex" (Cinsiyet) değişkeni seçilir.

# %%
plt.figure(figsize = (12, 6))

sns.violinplot(y = "day", x = "tip", data = tips, hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir violinplot göreceksiniz. Bu plot, verilerin y ekseni boyunca ("day") ve x ekseni boyunca ("tip") nasıl dağıldığını gösterir.
#
# #### Renkler ve Boyutlar
# - Keman grafikleri, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
#
# #### Eksenler
# - y ekseninde "day" (Gün), x ekseninde ise "tip" (Bahşiş) değişkenleri yer alır.
#
# #### Yorumlama
# - Violinplot, bahşiş verilerinin gün ve cinsiyet boyunca nasıl dağıldığını gösterir.
# - Y ekseni, hangi gün olduğunu; x ekseni ise bahşiş miktarını temsil eder.
# - Keman grafiklerinin genişliği, o gün ve cinsiyet için bahşiş miktarının sıklığını gösterir.
# - Bu grafik, "day" ve "sex" gibi kategorik değişkenlerle "tip" gibi bir sürekli değişkenin ilişkisini gözlemlemek için oldukça kullanışlıdır.

# %% [markdown]
# ### box grafkten daha güzel ve anlaşılır.
#
# ### split her sex in sağını ve solunu siler. Daha anlaşılır olmasını sağlar

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri setinden bir violinplot (keman grafiği) oluşturulmuş.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - y = "day", x = "tip", data = tips: y ekseni için "day" (Gün), x ekseni için "tip" (Bahşiş) ve veri seti olarak tips seçilir.
# - hue = "sex", split = "True", bw = 0.1: Renk tonu (hue) için "sex" (Cinsiyet), iki cinsiyetin verilerinin aynı keman grafiğinde gösterilmesi için split=True ve bant genişliği (bw) için 0.1 değeri seçilir.

# %%
plt.figure(figsize = (12, 6))

sns.violinplot(y = "day", x = "tip", data = tips, hue = "sex", split = "True", bw = 0.1
              );

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir violinplot göreceksiniz. Bu plot, verilerin y ekseni boyunca ("day") ve x ekseni boyunca ("tip") nasıl dağıldığını gösterir.
#
# #### Renkler ve Boyutlar
# Keman grafikleri, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
# split=True sayesinde her bir "day" için iki cinsiyetin keman grafiği aynı grafikte birleştirilmiştir.
#
# #### Eksenler
# y ekseninde "day" (Gün), x ekseninde ise "tip" (Bahşiş) değişkenleri yer alır.
#
# #### Yorumlama
# - Violinplot, bahşiş verilerinin gün ve cinsiyet boyunca nasıl dağıldığını gösterir.
# - Y ekseni, hangi gün olduğunu; x ekseni ise bahşiş miktarını temsil eder.
# - Keman grafiklerinin genişliği, o gün ve cinsiyet için bahşiş miktarının sıklığını gösterir.
# - split=True sayesinde, cinsiyetlere göre farklılıklar hemen gözlemlenebilir.
# - Bu grafik, "day" ve "sex" gibi kategorik değişkenlerle "tip" gibi bir sürekli değişkenin ilişkisini gözlemlemek için oldukça kullanışlıdır.

# %% [markdown]
# ## Swarm Plot

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri ile tips veri setinden bir swarmplot (yığın grafik) oluşturuluyor.
#
# - plt.figure(figsize = (10, 5)): Grafiğin boyutları 10x5 olarak belirleniyor.
# - y = "total_bill", data = tips: y ekseni için "total_bill" (Toplam Hesap) ve veri seti olarak tips seçiliyor.
# - size = 10: Her bir veri noktasının boyutu 10 olarak belirleniyor.
# - x = "smoker", hue = "sex": x ekseni için "smoker" (Sigara İçen) ve renk tonu (hue) için "sex" (Cinsiyet) değişkenleri seçiliyor.

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(y = "total_bill", data = tips, size = 10, x = "smoker", hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir swarmplot göreceksiniz. Bu, veri noktalarını x ekseni boyunca ("smoker") gruplayarak ve y ekseni boyunca ("total_bill") yerleştirerek oluşturuluyor.
#
# #### Renkler ve Boyutlar
# - Veri noktaları, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
# - Her bir veri noktası 10 boyutunda çizilmiştir.
#
# #### Eksenler
# - y ekseninde "total_bill" (Toplam Hesap), x ekseninde ise "smoker" (Sigara İçen) değişkenleri yer alır.
#
# #### Yorumlama
# - Swarmplot, veri noktalarının x ekseni boyunca ("smoker") nasıl gruplandığını ve y ekseni ("total_bill") boyunca nasıl dağıldığını gösterir.
# - hue = "sex" ile cinsiyete göre renk kodlanmış, bu da sigara içen ve içmeyen müşterilerin cinsiyet dağılımını gözlemlememize yardımcı olur.
# - Bu tür bir grafik, bir değişkenin (bu durumda "total_bill") diğer kategorik değişkenler (bu durumda "smoker" ve "sex") ile nasıl ilişkilendiğini gözlemlemek için son derece faydalıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri setinden bir swarmplot (yığın grafik) oluşturulmuş.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - x = "total_bill", data = tips: x ekseni için "total_bill" (Toplam Hesap) ve veri seti olarak tips seçilir.
# - size = 10: Her bir veri noktasının boyutu 10 olarak belirlenir.
# - y = "smoker": y ekseni için "smoker" (Sigara İçen) değişkeni seçilir.

# %%
plt.figure(figsize = (12, 6))
sns.swarmplot(x = "total_bill", data = tips, size = 10, y = "smoker");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, y ekseni boyunca ("smoker") gruplandırılmış ve x ekseni ("total_bill") boyunca yerleştirilmiş veri noktalarını göreceksiniz.
#
# #### Boyutlar
# - Her bir veri noktası 10 boyutunda çizilmiştir.
#
# #### Eksenler
# - x ekseninde "total_bill" (Toplam Hesap), y ekseninde ise "smoker" (Sigara İçen) değişkenleri yer alır.
#
# #### Yorumlama
# - Swarmplot, veri noktalarının y ekseni boyunca ("smoker") nasıl gruplandığını ve x ekseni ("total_bill") boyunca nasıl dağıldığını gösterir.
# - "Yes" ve "No" etiketleri, y ekseni boyunca sigara içen ve içmeyen müşterileri temsil eder.
# - x eksenindeki dağılım, toplam hesapların sigara içen ve içmeyen müşteriler arasında nasıl dağıldığını gösterir.
# - Bu grafik, "total_bill" değişkeninin "smoker" kategorik değişkeni ile nasıl bir ilişki içerisinde olduğunu gözlemlemek için kullanışlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri setinden bir swarmplot (yığın grafik) oluşturuluyor.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - x = "total_bill", data = tips: x ekseni için "total_bill" (Toplam Hesap) ve veri seti olarak tips seçilir.
# - size = 10: Her bir veri noktasının boyutu 10 olarak belirlenir.
# - y = "smoker", hue = "sex": y ekseni için "smoker" (Sigara İçen) ve renk tonu (hue) için "sex" (Cinsiyet) değişkenleri seçilir.

# %%
plt.figure(figsize = (12, 6))
sns.swarmplot(x = "total_bill", data = tips, size = 10, y = "smoker", hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir swarmplot göreceksiniz. Bu, veri noktalarını y ekseni boyunca ("smoker") gruplayarak ve x ekseni boyunca ("total_bill") yerleştirerek oluşturulur.
#
# #### Renkler ve Boyutlar
# - Veri noktaları, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
# - Her bir veri noktası 10 boyutunda çizilmiştir.
#
# #### Eksenler
# - x ekseninde "total_bill" (Toplam Hesap), y ekseninde ise "smoker" (Sigara İçen) değişkenleri yer alır.
#
# #### Yorumlama
# - Swarmplot, veri noktalarının y ekseni boyunca ("smoker") nasıl gruplandığını ve x ekseni ("total_bill") boyunca nasıl dağıldığını gösterir.
# - hue = "sex" ile cinsiyete göre renk kodlanmış, bu da sigara içen ve içmeyen müşterilerin cinsiyet dağılımını gözlemlememize yardımcı olur.
# - Bu tür bir grafik, bir değişkenin (bu durumda "total_bill") diğer kategorik değişkenler (bu durumda "smoker" ve "sex") ile nasıl ilişkilendiğini gözlemlemek için son derece faydalıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Matplotlib ve Seaborn kütüphaneleri kullanılarak tips veri setinden bir swarmplot (yığın grafik) oluşturuluyor.
#
# - plt.figure(figsize = (12, 6)): Grafiğin boyutları 12x6 olarak belirlenir.
# - x = "total_bill", data = tips: x ekseni için "total_bill" (Toplam Hesap) ve veri seti olarak tips seçilir.
# - size = 10: Her bir veri noktasının boyutu 10 olarak belirlenir.
# - y = "smoker", hue = "sex": y ekseni için "smoker" (Sigara İçen) ve renk tonu (hue) için "sex" (Cinsiyet) değişkenleri seçilir.
# - dodge = True: Aynı kategorideki farklı hue değerlerini (bu durumda cinsiyet) ayırmak için kullanılır.

# %%
plt.figure(figsize = (12, 6))
sns.swarmplot(x = "total_bill", data = tips, size = 10, y = "smoker", hue = "sex", dodge = True);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir swarmplot göreceksiniz. Bu, veri noktalarını y ekseni boyunca ("smoker") gruplayarak ve x ekseni boyunca ("total_bill") yerleştirerek oluşturulur.
#
# #### Renkler ve Boyutlar
# - Veri noktaları, "sex" (Cinsiyet) değişkenine göre renk kodlanmıştır.
# - Her bir veri noktası 10 boyutunda çizilmiştir.
#
# #### Eksenler
# - x ekseninde "total_bill" (Toplam Hesap), y ekseninde ise "smoker" (Sigara İçen) değişkenleri yer alır.
#
# #### Yorumlama
# - Swarmplot, veri noktalarının y ekseni boyunca ("smoker") nasıl gruplandığını ve x ekseni ("total_bill") boyunca nasıl dağıldığını gösterir.
# - hue = "sex" ile cinsiyete göre renk kodlanmış, bu da sigara içen ve içmeyen müşterilerin cinsiyet dağılımını gözlemlememize yardımcı olur.
# - dodge=True sayesinde, sigara içen ve içmeyen kategoriler içindeki cinsiyetlere göre ayrılmış noktalar gözlemlenebilir.
#
# Bu tür bir grafik, bir değişkenin (bu durumda "total_bill") diğer kategorik değişkenler (bu durumda "smoker" ve "sex") ile nasıl ilişkilendiğini gözlemlemek için son derece faydalıdır.

# %% [markdown]
# # Comparison Plot

# %% [markdown]
# ## Jointplot
# İçiçe plotlar çizer. iki farklı grafiği aynı anda görmeyi sağlar.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Seaborn'un jointplot fonksiyonu kullanılarak tips veri setinde "total_bill" (toplam hesap) ve "tip" (bahşiş) değişkenleri arasındaki ilişki gösterilmektedir.
#
# data = tips: Veri seti olarak tips kullanılır.
# x = "total_bill", y = "tip": x ekseni için "total_bill" ve y eksen için "tip" değişkenleri seçilir.
# kind = "scatter": Grafik türü olarak saçılım (scatter) grafiği seçilir.
# alpha = 0.7: Veri noktalarının saydamlığı 0.7 olarak ayarlanır. Bu, veri noktalarının üst üste geldiği alanlarda yoğunluğu gözlemlemek için yararlıdır.

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "scatter", alpha=0.7);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# - Çıktı, merkezi bir saçılım grafiği ve bu grafiğin x ve y eksenleri boyunca yer alan iki histogramı içerir.
#
# #### Renkler ve Saydamlık
# - Noktaların saydamlığı alpha=0.7 ile ayarlanmıştır, bu da veri noktalarının üst üste geldiği alanlarda yoğunluğu daha iyi görmemize olanak tanır.
#
# #### Eksenler
# - x ekseninde "total_bill" (Toplam Hesap) ve y ekseninde "tip" (Bahşiş) yer alır.
#
# #### Yorumlama
# Merkezi saçılım grafiği, "total_bill" ve "tip" arasındaki ilişkiyi gösterir. Eğer noktalar belirli bir eğimle yerleşmişse, bu değişkenler arasında bir korelasyon olduğunu gösterir.
#
# x ve y eksenleri boyunca histogramlar, bu değişkenlerin kendi dağılımlarını gösterir. Bu histogramlar, "total_bill" ve "tip" değişkenlerinin frekans dağılımını anlamamıza yardımcı olur.
#
# Bu tür bir grafik, iki değişken arasındaki ilişkiyi anlamak ve aynı zamanda her bir değişkenin dağılımını gözlemlemek için çok kullanışlıdır.

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "hex");

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "kde", shade = True);

# %% [markdown]
# ## Pair Plot
# Datanın içindeki kategorik olsa bile numerik(float, int)  verilerin tüm grafiğiklerini verir. data içinde hızlı bir göz atmak için kullanılmaktadır. Tek değişkenli ve çok teğişkenli veri setlerini tanımanıza fayda sağlar.
#
# avantajı içine sadece datayı veriyorum. o kendi kendine ilişkileri kuruyor. dikkat edin x ve y vermiyorum.
#
# matplotlib'den güçlü yönü renkleri kullanabilmek.
#
# renkler için link = https://seaborn.pydata.org/tutorial/color_palettes.html
#
# corner = True denildiğinde ayna yansımasıunı almıyor

# %%
sns.pairplot(tips); # sns.pairplot(data = tips);

# %%
sns.pairplot(tips, hue = "sex");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# - Çıktıda, tips veri setinin numerik değişkenleri arasındaki ilişkileri gösteren bir dizi grafik yer alır.
#
# #### Renkler
# - "viridis" renk paleti kullanılır ve cinsiyete göre renk kodlaması yapılır.
#
# #### Eksenler
# - Her bir alt grafikin (facet) x ve y eksenleri tips veri setinin numerik sütunlarıdır.
#
# #### Yorumlama
# Saçılım grafikleri, iki değişken arasındaki ilişkiyi gösterir. Eğer bir trend varsa, iki değişken arasında korelasyon olduğu anlaşılır.
#
# Köşegen grafikler, değişkenlerin kendi dağılımlarını gösterir. diag_kind = "hist" parametresi ile bu grafikler, değişkenlerin frekans dağılımını histogram şeklinde gösterir.
#
# diag_kind="hist" kullanılarak, veri setindeki her bir numerik değişkenin kendi dağılımı hakkında daha fazla bilgi alınabilir. Bu, veri setindeki numerik değişkenler arasındaki ilişkileri hızlı bir şekilde gözlemlemek ve anlamak için son derece yararlıdır.

# %%
sns.pairplot(tips, hue = "sex", palette = "viridis", diag_kind = "hist"); #kind = "reg" de verilebilir.

# %% [markdown]
# Çıktı Açıklaması
# Genel Bakış
# Çıktıda, tips veri setinin numerik değişkenleri arasındaki ilişkileri gösteren bir dizi grafik yer alır.
#
# Renkler
# "viridis" renk paleti kullanılır ve cinsiyete göre renk kodlaması yapılır.
# Eksenler
# Her bir alt grafikin (facet) x ve y eksenleri tips veri setinin numerik sütunlarıdır.
# Yorumlama
# Saçılım grafikleri, iki değişken arasındaki ilişkiyi gösterir. Eğer bir trend varsa, iki değişken arasında korelasyon olduğu anlaşılır.
# Köşegen grafikler, değişkenlerin kendi dağılımlarını gösterir. diag_kind = "hist" parametresi ile bu grafikler, değişkenlerin frekans dağılımını histogram şeklinde gösterir.
# diag_kind="hist" kullanılarak, veri setindeki her bir numerik değişkenin kendi dağılımı hakkında daha fazla bilgi alınabilir. Bu, veri setindeki numerik değişkenler arasındaki ilişkileri hızlı bir şekilde gözlemlemek ve anlamak için son derece yararlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, Seaborn'un pairplot fonksiyonu kullanılarak tips veri setindeki numerik değişkenler arasındaki ilişkileri gösterir. kind="hist" parametresi ile her bir ikili kombinasyon için histogramlar çizilir.
#
# hue = "sex", palette = "viridis": Veri noktaları cinsiyete ("sex") göre renklendirilir ve "viridis" renk paleti kullanılır.
# kind = "hist": İkili kombinasyonlar için histogramlar çizilir. Ayrıca, kind="reg" da kullanılabilir, bu durumda her bir saçılım grafiğine bir regresyon çizgisi eklenecektir.

# %%
sns.pairplot(tips, hue = "sex", palette = "viridis", kind = "hist"); #kind = "reg" de verilebilir.

# %% [markdown]
# Bu plotta her grafikten aslında iki tane var bunun yansımasını kaldırmak için yani unique hale getirmek için corner kodu yazılıyor.

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, tips veri setinin numerik değişkenleri arasındaki ilişkileri gösteren bir dizi grafik yer alır.
#
# #### Renkler
# - "viridis" renk paleti kullanılır ve cinsiyete göre renk kodlaması yapılır.
#
# #### Eksenler
# - Her bir alt grafikin (facet) x ve y eksenleri tips veri setinin numerik sütunlarıdır.
#
# #### Yorumlama
# Saçılım grafikleri ve histogramlar, iki değişken arasındaki ilişkiyi ve değişkenlerin kendi dağılımlarını gösterir.
# kind = "hist" parametresi sayesinde, grafikler verinin dağılımını daha fazla vurgular.
#
# kind = "reg" kullanıldığında, saçılım grafiklerine en iyi uyum sağlayan regresyon çizgileri de çizilir. Bu, değişkenler arasındaki ilişkinin doğrusallığını değerlendirmek için kullanılır.
#
# Bu tür grafikler, veri setindeki numerik değişkenler arasındaki ilişkileri hızlı bir şekilde gözlemlemek ve anlamak için son derece yararlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, Seaborn'un pairplot fonksiyonu kullanılarak tips veri setindeki numerik değişkenler arasındaki ilişkileri gösterir. pairplot fonksiyonu, PairGrid'in bir üst seviye sürümüdür ve bu fonksiyon daha otomatik bir işlem sağlar.
#
# hue = "sex", palette = "viridis": Veri noktaları cinsiyete ("sex") göre renklendirilir ve "viridis" renk paleti kullanılır.
# corner = True: Sadece üst üçgen formundaki grafikler çizilir, böylece aynı bilgilerin tekrar etmesi önlenir.

# %%
sns.pairplot(tips, hue = "sex", palette = "viridis", corner =True);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, tips veri setinin numerik değişkenleri arasındaki ilişkileri gösteren bir dizi grafik yer alır.
#
# #### Renkler
# - "viridis" renk paleti kullanılır ve cinsiyete göre renk kodlaması yapılır.
#
# #### Eksenler
# - Her bir alt grafikin (facet) x ve y eksenleri tips veri setinin numerik sütunlarıdır.
#
# #### Yorumlama
# Üst üçgen formundaki saçılım grafikleri, iki değişken arasındaki ilişkiyi gösterir. Eğer bir trend varsa, iki değişken arasında korelasyon olduğu anlaşılır.
#
# Köşegen grafikler, değişkenlerin kendi dağılımlarını gösterir. Bu, her değişkenin frekans dağılımının neye benzediğini anlamak için kullanışlıdır.
#
# Bu versiyon corner=True parametresi ile sadece üst üçgen formundaki grafikleri çizer, bu da grafiklerin daha hızlı oluşturulmasını ve daha kolay yorumlanmasını sağlar. Bu tür grafikler, veri setindeki numerik değişkenler arasındaki ilişkileri hızlı bir şekilde gözlemlemek ve anlamak için oldukça kullanışlıdır.

# %%
sns.color_palette("viridis", as_cmap = True)

# %% [markdown]
# ### Pair Grid

# %% [markdown]
# pair grid sağladığı en büyük avantaj grafikleri konumuna göre özelleştirebiliyoruz. Bunu yaparken sns.pair grid kodunu bir değişkene atıyoruz

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, Seaborn'un PairGrid fonksiyonu ile tips veri setindeki numerik değişkenler arasındaki ilişkileri farklı grafik türleri kullanarak gösterir. Bu versiyonda, köşegen grafikler için sns.histplot kullanılmıştır, diğer kısımlar ise bir önceki örnekle aynıdır.
#
# - hue = "sex", palette = "rocket": Veri noktaları cinsiyete ("sex") göre renklendirilir ve "rocket" renk paleti kullanılır.
# - g.map_upper(sns.scatterplot): Üst üçgen formundaki grafiklere saçılım grafikleri yerleştirilir.
# - g.map_diag(sns.histplot): Köşegen grafiklere, değişkenlerin dağılımını gösteren histogramlar yerleştirilir.
# - g.map_lower(sns.kdeplot, shade = True, color = "y"): Alt üçgen formundaki grafiklere yoğunluk tahmin grafiği (KDE) yerleştirilir. Yoğunluk grafiği gölgeli ve sarı renkte gösterilir.

# %%
g = sns.PairGrid(tips, hue = "sex", palette = "rocket");

g = g.map_upper(sns.scatterplot)
g = g.map_diag(sns.histplot)
g = g.map_lower(sns.kdeplot, shade = True, color = "y");

g = g.add_legend ();

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, tips veri setinin numerik değişkenleri arasındaki ilişkileri gösteren bir dizi grafik yer alır.
#
# #### Renkler
# - "rocket" renk paleti kullanılır ve cinsiyete göre renk kodlaması yapılır.
#
# #### Eksenler
# - Her bir alt grafikin (facet) x ve y eksenleri tips veri setinin numerik sütunlarıdır.
#
# #### Yorumlama
# Üst üçgen formundaki saçılım grafikleri, iki değişken arasındaki ilişkiyi gösterir. Eğer bir trend varsa, iki değişken arasında korelasyon olduğu anlaşılır.
#
# Köşegen grafikler, değişkenlerin kendi dağılımlarını gösterir. Bu, her değişkenin frekans dağılımının neye benzediğini anlamak için kullanışlıdır.
#
# Alt üçgen formundaki yoğunluk tahmin grafikleri, iki değişken arasındaki ilişkiyi daha pürüzsüz bir formda gösterir.
#
# Bu versiyonda, sns.histplot kullanılarak köşegen grafiklerde değişkenlerin histogramları daha net bir şekilde çizilmiştir.
#
# Bu grafikler, veri setindeki numerik değişkenler arasındaki ilişkileri hızlı bir şekilde gözlemlemek için son derece yararlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, Seaborn'un PairGrid fonksiyonu ile tips veri setindeki numerik değişkenlerin birbirine göre olan ilişkilerini farklı grafik türleri kullanarak gösterir.
#
# - hue = "sex", palette = "rocket": Veri noktaları cinsiyete ("sex") göre renklendirilir ve "rocket" renk paleti kullanılır.
# - g.map_upper(sns.scatterplot, s = 200, edgecolor = "w"): Üst üçgen formundaki grafiklere saçılım grafikleri yerleştirilir. Veri noktalarının boyutu 200 ve kenar rengi beyaz olarak ayarlanmıştır.
#
# - g.map_diag(sns.distplot): Köşegen grafiklere, değişkenlerin dağılımını gösteren histogramlar yerleştirilir.
# - g.map_lower(sns.kdeplot, shade = True, color = "y"): Alt üçgen formundaki grafiklere yoğunluk tahmin grafiği (KDE) yerleştirilir. Yoğunluk grafiği gölgeli ve sarı renkte gösterilir.

# %%
g = sns.PairGrid(tips, hue = "sex", palette = "rocket");

g = g.map_upper(sns.scatterplot, s = 200, edgecolor = "w")
g = g.map_diag(sns.distplot)
g = g.map_lower(sns.kdeplot, shade = True, color = "y");

g = g.add_legend ();

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# - Çıktıda, tips veri setinin numerik değişkenleri arasındaki ilişkileri gösteren bir dizi grafik yer alır.
#
# #### Renkler
# - "rocket" renk paleti kullanılır ve cinsiyete göre renk kodlaması yapılır.
#
# #### Eksenler
# Her bir alt grafikin (facet) x ve y eksenleri tips veri setinin numerik sütunlarıdır.
#
# #### Yorumlama
# Üst üçgen formundaki saçılım grafikleri, iki değişken arasındaki ilişkiyi gösterir. Eğer bir trend varsa, iki değişken arasında korelasyon olduğu anlaşılır.
#
# Köşegen grafikler, değişkenlerin kendi dağılımlarını gösterir. Bu, her değişkenin frekans dağılımının neye benzediğini anlamak için kullanışlıdır.
#
# Alt üçgen formundaki yoğunluk tahmin grafikleri, iki değişken arasındaki ilişkiyi daha pürüzsüz bir formda gösterir.
#
# Bu tür grafikler, veri setindeki numerik değişkenler arasındaki ilişkileri hızlı bir şekilde gözlemlemek ve anlamak için son derece yararlıdır.

# %% [markdown]
# ## FacetGrid

# %% [markdown]
# facet grid de biraz daha özelleştirebiliyoruz kategorik değişken verip veriyi daha detaylı inceleyebiliyoruz. bununda syntaxi pair gride benziyor yine bir değişkene atayacağız.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, Seaborn'un FacetGrid ve map fonksiyonlarını kullanarak tips veri seti üzerinden farklı yemek zamanları ("time") ve sigara içme durumları ("smoker") için "total_bill" (toplam hesap) dağılımlarını gösteren histogramlar oluşturur.
#
# col="time" ve row="smoker": Grafikler yemek zamanına ("time") ve sigara içip içmeme durumuna ("smoker") göre ayrılır.
# g.map(plt.hist, "total_bill"): Her bir alt grafik ("facet"), "total_bill" (toplam hesap) için bir histogram oluşturur.

# %%
g = sns.FacetGrid(data = tips, col="time", row="smoker")
g = g.map(plt.hist, "total_bill")

# %% [markdown]
# Bakın tek değişken verdim (total bill) bu sebeple otomatik olarak distplot verdi yani histogram.
#
#
# peki iki değişken versem ne ile vermem gerekir

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, farklı yemek zamanları (Öğle veya Akşam) ve sigara içip içmeme durumları (Evet veya Hayır) için "total_bill" (toplam hesap) değişkeninin histogramları yer alır.
#
# #### Renkler
# - Varsayılan renk paleti kullanıldığı için genellikle mavi tonlarını göreceksiniz.
# #### Eksenler
# - X Ekseni: Her bir alt grafikte (facet), x ekseninde "total_bill" (toplam hesap) yer alır.
# - Y Ekseni: Y ekseninde ise frekans (sayı) görülecektir.
#
# #### Yorumlama
# Grafikler, yemek zamanına ve sigara içme durumuna göre toplam hesap dağılımlarını gösterir.
#
# Örneğin, öğle yemeği zamanında sigara içen ve içmeyen müşteriler arasında toplam hesap miktarında bir fark olup olmadığı kolayca gözlemlenebilir.
#
# Histogramlar, toplam hesap miktarının ne kadar varyans gösterdiğini ve en sık hangi aralıklarda değer aldığını da gösterir.
#
# Bu tür çoklu grafikler, verinin farklı alt gruplar arasında nasıl değiştiğini anlamak için oldukça yararlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, Seaborn'un FacetGrid ve map fonksiyonlarını kullanarak, tips veri setinden çoklu grafikler (facets) oluşturur.
#
# - col="time" ve row="smoker": Grafikler, yemek zamanına ("time") ve sigara içip içmeme durumuna ("smoker") göre ayrılır.
# - hue="sex": Veri noktaları cinsiyete ("sex") göre renklendirilir.
# - palette="viridis": "viridis" renk paleti kullanılır.
# - g.map(sns.scatterplot, "total_bill","tip", s = 100): Her bir alt grafikte ("facet"), toplam hesap ("total_bill") ve bahşiş ("tip") arasındaki ilişki saçılım grafiği (scatterplot) ile gösterilir. Her bir veri noktasının boyutu s=100 olarak ayarlanır.
# - g.add_legend(): Renk kodlaması için bir açıklama (legend) ekler.

# %%
g = sns.FacetGrid(data = tips, col="time", row="smoker", hue = "sex", palette = "viridis")
g = g.map(sns.scatterplot, "total_bill","tip", s = 100)

g = g.add_legend();

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktı, farklı kombinasyonlara göre ayrılmış bir dizi saçılım grafiği (scatterplot) gösterir: Yemek zamanı (Öğle veya Akşam) ve sigara içme durumu (Evet veya Hayır).
#
# #### Renkler
# - "viridis" renk paleti kullanılarak, cinsiyete göre renklendirilmiş veri noktalarını göreceksiniz.
# Eksenler
# - X Ekseni: Her bir alt grafikte (facet), x ekseninde "total_bill" (toplam hesap) yer alır.
# - Y Ekseni: Y ekseninde ise "tip" (bahşiş) görülecektir.
#
# #### Yorumlama
# Grafikler, yemek zamanına ve sigara içip içmeme durumuna göre nasıl bir değişiklik gösterdiğini açıkça ortaya koyar.
#
# Ayrıca, cinsiyete göre renk kodlaması sayesinde, bahşiş ve toplam hesap arasındaki ilişkinin cinsiyete göre nasıl değiştiğini gözlemlemek de mümkündür.
#
# Saçılım grafikleri, "total_bill" ile "tip" arasındaki ilişkiyi gösterir. Eğer bir trend gözlemleniyorsa, bu genellikle iki değişken arasında bir korelasyon olduğunu gösterir.
#
# Bu çoklu grafikler, veriyi farklı açılardan incelemek ve içgörüler elde etmek için oldukça kullanışlıdır.

# %% [markdown]
# ## Heatmap
#
# içine matris grafik çizecek fonksiyon vermek gerekirörneğin corr

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri setinin korelasyon matrisini (tips.corr()) hesaplayarak Seaborn'un sns.heatmap fonksiyonu ile bir ısı haritası (heatmap) oluşturur.
#
# Bu versiyonda, annot ve diğer özelleştirme parametreleri belirtilmemiştir, bu nedenle sadece renklerle kodlanmış bir ısı haritası oluşturulur. Varsayılan renk paleti kullanılır.

# %%
sns.heatmap(tips.corr());

# %% [markdown]
# #### içine değer yazıp (annot =True) daha net görebiliriz.

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, bir ısı haritası formatında korelasyon matrisi göreceksiniz.
#
# #### Renkler
# Seaborn'un varsayılan renk paleti kullanılır, bu genellikle mavi tonları içerir.
# #### Eksenler
# - X Ekseni: tips veri setinin sütun isimleri (özellikleri) yer alır.
# - Y Ekseni: Yine, tips veri setinin aynı sütun isimleri (özellikleri) yer alır.
#
# #### Yorumlama
# Isı haritası, veri setindeki özellikler arasındaki korelasyonları renk gradyanı ile görsel olarak sunar.
#
# Örneğin, 'total_bill' (toplam hesap) ve 'tip' (bahşiş) arasında yüksek bir korelasyon varsa, bu iki özellik arasında belirli bir renk (bağlı olarak varsayılan renk paletine) daha belirgin olacaktır.
#
# Bu basit ısı haritası, özellikler arasındaki ilişkileri gözlemlemek için hızlı ve etkili bir yöntem sağlar. Ancak, korelasyon katsayılarını görmek için annot=True gibi parametrelerin eklenmesi genellikle daha yararlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri setinin korelasyon matrisini (tips.corr()) hesaplayarak bir ısı haritası (heatmap) oluşturur. Seaborn'un sns.heatmap fonksiyonu kullanılır.
#
# annot=True: Isı haritası üzerindeki her bir hücreye korelasyon katsayılarını ekler.
# Bu kodda, renk paleti (cmap) ve merkez (center) parametreleri belirtilmemiş, bu yüzden Seaborn'un varsayılan renk paleti kullanılır.

# %%
sns.heatmap(tips.corr(), annot = True);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir ısı haritası formatında korelasyon matrisi göreceksiniz.
#
# #### Renkler
# Varsayılan renk paleti genellikle mavi ve kırmızı renk tonları arasında değişir.
# #### Eksenler
# - X Ekseni: tips veri setinin sütun isimleri (özellikleri) yer alır.
# - Y Ekseni: Yine, tips veri setinin aynı sütun isimleri (özellikleri) yer alır.
#
# #### Yorumlama
#
# Isı haritası, veri setindeki özellikler arasındaki korelasyonları görsel olarak sunar.
#
# annot=True parametresi sayesinde, her bir hücrenin üzerinde korelasyon katsayıları görülebilir. Bu, hızlı bir yorumlama ve karşılaştırma için oldukça yararlıdır.
#
# Örneğin, 'total_bill' (toplam hesap) ve 'tip' (bahşiş) arasında yüksek bir korelasyon varsa, bu iki özellik arasında daha açık ya da koyu bir renk (bağlı olarak varsayılan renk paletine) görülecektir.
#
# Isı haritası, özellikler arasındaki ilişkileri hızlı ve etkili bir şekilde görselleştirmek için yararlı bir araçtır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneği, tips veri setinin korelasyon matrisini hesaplar (tips.corr()) ve bu korelasyon matrisini sns.heatmap fonksiyonu ile bir ısı haritası (heatmap) olarak görselleştirir.
#
# annot=True: Isı haritası üzerindeki her hücreye korelasyon katsayılarını yazar.
# cmap="cubehelix": Kullanılacak renk paletini "cubehelix" olarak belirler. Bu renk paleti, koyu renklerden açık renklere doğru bir gradyan sunar.

# %%
sns.heatmap(tips.corr(), annot = True, cmap = "cubehelix");

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir ısı haritası formatında korelasyon matrisi görülür.
#
# #### Renkler
# - 'cubehelix' renk paleti genellikle koyu renklerden (örneğin, siyah) açık renklere (örneğin, beyaz) doğru bir renk gradyanı sunar.
# #### Eksenler
# - X Ekseni: tips veri setinin özellikleri (sütun isimleri) yer alır.
# - Y Ekseni: Aynı özelliklerin (sütun isimlerinin) yer aldığı bir eksen görülür.
# #### Yorumlama
#
# Isı haritası, özellikler arası korelasyon katsayılarını görsel bir biçimde sunar.
#
# Özellikler arasında yüksek pozitif ya da negatif korelasyonlar varsa, bu hücreler öne çıkan renklerle gösterilir.
#
# Örneğin, 'total_bill' (toplam hesap) ile 'tip' (bahşiş) arasındaki korelasyon yüksekse, bu iki özellik arasında daha açık bir renk görülecektir.
#
# Isı haritası, özellikler arası korelasyonları hızlı bir şekilde değerlendirmek ve analiz etmek için yararlı bir araçtır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod parçası, Seaborn'un color_palette fonksiyonu ile "cubehelix" renk paletini bir renk haritası (colormap) olarak yüklemeye çalışır. as_cmap=True parametresi ile, döndürülen değer bir Matplotlib colormap objesi olacaktır.
#
# Fakat, aynı şekilde sns.color_palette genellikle renk paleti olarak bir liste döndürür ve as_cmap=True parametresi bu fonksiyon için geçerli değildir. Eğer bir colormap objesi istiyorsanız, doğrudan Matplotlib fonksiyonları kullanılabilir.

# %%
sns.color_palette("cubehelix", as_cmap=True)

# %% [markdown]
# center ile buradaki renk kodu ile oynerken centre ye verdiğimiz değer korelasyon tablosunda o değerleri alan kutucukları renk skalasının ortasındaki yani merkezindeki renge boyuyor. Düşük olanları under tarafa yüksek olanları over tarafına doğru renklendiriyor.

# %% [markdown]
# ## Çıktı Açıklaması
# Bu kod çalıştırıldığında, bir hata mesajı alabilirsiniz. sns.color_palette fonksiyonu bir liste döndürür ve as_cmap=True parametresi genellikle kabul edilmez.
#
# ### Yorumlama
# Eğer "cubehelix" renk haritasını bir colormap olarak kullanmak istiyorsanız, Matplotlib'in cm modülünü kullanabilirsiniz.

# %% [raw]
# Örneğin:
#
# import matplotlib.pyplot as plt
#
# cmap = plt.cm.cubehelix

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, tips veri seti üzerinde korelasyon matrisi hesaplanmaktadır (tips.corr()). Hesaplanan korelasyon matrisi, sns.heatmap fonksiyonu kullanılarak bir ısı haritası (heatmap) olarak görselleştirilmektedir.
#
# annot=True: Korelasyon katsayılarını ısı haritası üzerinde göstermek için kullanılır.
# cmap="cubehelix": Kullanılacak renk paletini 'cubehelix' olarak ayarlar. Bu palet genellikle siyahtan beyaza doğru bir renk geçişi sunar.
# center=0.5: Renk paletinin merkezini 0.5 olarak belirler, bu da pozitif ve negatif korelasyon değerlerinin nasıl renklendirileceğini etkiler.

# %%
sns.heatmap(tips.corr(), annot = True, cmap = "cubehelix", center = 0.5);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, ısı haritası formatında bir korelasyon matrisi göreceksiniz.
#
# #### Renkler
# - 'cubehelix' renk paleti genellikle karanlık renklerden (siyah) açık renklere (beyaz) doğru bir renk gradyanı sunar.
# - center=0.5 ile, 0.5 değeri renk skalasının merkezi olarak belirlenmiştir.
# #### Eksenler
# - X Ekseni: tips veri setindeki özelliklerin (sütunların) isimleri yer alır.
# - Y Ekseni: Yine aynı özelliklerin isimleri yer alır.
# #### Yorumlama
# Isı haritasında gördüğünüz korelasyon katsayıları ve renkler, özellikler arasındaki ilişkinin gücü hakkında bilgi verir.
# Örneğin, 'total_bill' (toplam hesap) ve 'tip' (bahşiş) arasında yüksek bir korelasyon varsa, bu iki özellik arasında daha açık bir renk göreceksiniz.
#
# center=0.5 parametresiyle, 0.5'e yakın korelasyon katsayıları belirli bir renkle vurgulanacaktır, böylece daha kolay fark edileceklerdir.
#
# Bu tür görselleştirmeler, veri setindeki özellikler arasındaki ilişkileri hızlı ve etkili bir şekilde anlamak için kullanılır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod parçası, Seaborn'un color_palette fonksiyonu ile "viridis" renk paletini bir renk haritası (colormap) olarak yüklemeye çalışır. as_cmap=True parametresi sayesinde, döndürülen değer bir Matplotlib colormap objesi olur. Ancak, önemli bir not olarak, sns.color_palette fonksiyonu aslında bir colormap döndürmez, bu yüzden bu kod bir hata üretebilir. Eğer bir colormap objesi istiyorsanız, doğrudan Matplotlib fonksiyonları kullanılabilir.

# %%
sns.color_palette("viridis", as_cmap=True)

# %% [markdown]
# ## Çıktı Açıklaması
# Bu kod çalıştırıldığında, bir hata mesajı alabilirsiniz. sns.color_palette fonksiyonu bir liste döndürür ve as_cmap=True parametresi genellikle kabul edilmez.
#
# Yorumlama
# Eğer "viridis" renk haritasını bir colormap olarak kullanmak istiyorsanız, Matplotlib'in cm modülünü kullanabilirsiniz.

# %% [raw]
# Örneğin:
#
# import matplotlib.pyplot as plt
#
# cmap = plt.cm.viridis

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, tips veri seti üzerinden korelasyon matrisi hesaplanıyor (tips.corr()). Sonrasında, bu korelasyon matrisi sns.heatmap fonksiyonu ile bir ısı haritası (heatmap) olarak görselleştiriliyor.
#
# annot=True: Korelasyon değerlerini harita üzerindeki ilgili hücrelere yazdırır.
# cmap="viridis": Kullanılacak renk haritasını 'viridis' olarak belirler.
# center=0.9: Renk haritasının merkezini 0.9 olarak belirler. Bu, pozitif ve negatif değerlerin nasıl renklendirileceğini etkiler.

# %%
sns.heatmap(tips.corr(), annot = True, cmap = "viridis", center = 0.9);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, ısı haritası formunda bir korelasyon matrisi görülecektir.
#
# #### Renkler
# - Yeşil renk tonları, pozitif korelasyonu gösterir.
# - Mor renk tonları, negatif korelasyonu gösterir.
# - center=0.9 parametresiyle, 0.9 değeri etrafında bir renk dengesi kurulmuştur.
# #### Eksenler
# - X Ekseni: tips veri setindeki özelliklerin (sütunların) isimleri yer alır.
# - Y Ekseni: Yine aynı özelliklerin isimleri yer alır.
# #### Yorumlama
# Isı haritasında, korelasyon katsayılarına göre renkler atanmıştır. Bu, hangi özelliklerin birbiriyle ne derece ilişkili olduğunu hızlıca görmemizi sağlar.
#
# Örneğin, 'total_bill' (toplam hesap) ve 'tip' (bahşiş) arasındaki korelasyon yüksekse, bu iki özellik arasında yeşil tonlu bir renk göreceksiniz.
#
# center=0.9 sayesinde, 0.9 değerine yaklaşan korelasyonlar daha belirgin bir yeşil ton alacaktır, böylece dikkat çekeceklerdir.
#
# Bu tür görselleştirmeler, özellikler arası ilişkileri anlamak ve veri setini daha iyi yorumlamak için oldukça kullanışlıdır.

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, öncelikle tips adında bir veri seti varsayılıyor (muhtemelen Seaborn kütüphanesinden yüklenmiş). .corr() metodu ile bu veri setinin özellikleri (sütunlar) arasındaki korelasyon matrisi hesaplanıyor. Sonra, bu korelasyon matrisi sns.clustermap fonksiyonu ile bir kümeleme haritası (clustermap) şeklinde görselleştiriliyor. annot=True parametresi ile matristeki her bir hücreye korelasyon katsayıları yazdırılıyor.

# %%
sns.clustermap(tips.corr(), annot=True );

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda bir korelasyon matrisinin kümeleme haritasını göreceksiniz. Hem satırlar hem de sütunlar, korelasyon değerlerine göre kümelenmiş olacaktır.
#
# #### Renkler
# Renk kodlaması, hücrelerin korelasyon katsayılarını temsil eder. Genellikle -1 ile 1 arasında bir değer alır:
#
# - 1'e yakın değerler, pozitif korelasyonu gösterir.
# - -1'e yakın değerler, negatif korelasyonu gösterir.
# - 0, zayıf ya da hiçbir korelasyonu gösterir.
# #### Eksenler
# - X Ekseni: tips veri setindeki özelliklerin (sütunların) isimleri yer alır.
# - Y Ekseni: Yine aynı özelliklerin isimleri yer alır.
# #### Yorumlama
# Kümeleme haritası, hangi özelliklerin birbiriyle daha fazla ilişkili olduğunu görmemize yardımcı olur. Yüksek pozitif ya da negatif korelasyonlu özellikler bir arada kümelenir.
#
# Örneğin, eğer 'toplam_hesap' ve 'bahşiş' sütunları yüksek bir korelasyon katsayısına sahipse, bu iki sütun bir arada kümelenmiş olacaktır. Bu durum, toplam hesap arttıkça bahşişin de genellikle arttığını gösterir.
#
# 1 veya -1'e yakın korelasyon katsayıları, özellikler arasında güçlü bir ilişkinin olduğunu gösterir. Ancak bu illa ki bir nedensellik ilişkisi olduğu anlamına gelmez, sadece bir ilişkinin varlığını gösterir.
#
# Bu tür görselleştirmeler genellikle veri setinin özellikleri arasındaki ilişkileri hızlı ve etkili bir şekilde değerlendirmek için kullanılır.

# %%
iris = sns.load_dataset("iris")

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# Data içindeki hiyerarşik ilişkileri bize gösteriyor. Bunu daha çok machine learning de kullanacağız
#
# Matris veri kümesinin hiyerarşik olarak kümelenmiş bir ısı haritasını çizer .
#
# Görülen çizgiler dendogram denilmektedir. Bu kapsamda bu dendogramların çizimine yönelik bazı detaylar var bunlar
#
# Hierarchical
#
# Agglomerative
#
# Clustering
#
# burada basitçe dendogram ile aradaki mesefaeye bakarak bir birleri ile gruplamalar yapar bir şekilde çalışmakta kodumuz

# %% [markdown]
# ## Kod Açıklaması
# Bu kod örneğinde, Seaborn kütüphanesinin load_dataset fonksiyonu kullanılarak meşhur "Iris" veri seti yükleniyor. Daha sonra, "species" (tür) sütunu pop metodu ile veri setinden çıkarılıyor. Bu işlemden sonra, kalan sayısal değişkenlerle bir "Clustermap" (Kümeleme Haritası) oluşturuluyor. annot=True parametresi, hücrelerin üzerinde sayısal değerlerin gösterilmesini sağlıyor.

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
sns.clustermap(iris, annot = True);

# %% [markdown]
# ## Çıktı Açıklaması
# ### Genel Bakış
# Çıktıda, iki boyutlu bir ızgara (matris) şeklinde bir kümeleme haritası göreceksiniz. Hem satırlar hem de sütunlar, benzerliklerine göre kümelenmiş olacaktır.
#
# #### Renkler
# Renk kodlaması, hücrelerin değerlerini temsil eder. Renk skalasını genellikle haritanın yanında görebilirsiniz. Daha koyu renkler, daha yüksek değerleri; daha açık renkler ise daha düşük değerleri temsil eder.
#
# #### Eksenler
# - X Ekseni: Iris veri setindeki özelliklerin (sütunların) isimleri yer alır.
# - Y Ekseni: İlgili gözlemler (satırlar) yer alır, fakat genellikle numara yerine kümelenmeye dayalı bir sıralama gösterilir.
# ### Yorumlama
# Kümeleme haritasında benzer değerlere sahip gözlemler ve özellikler bir araya getirilmiştir. Bu, hangi özelliklerin birbiriyle daha fazla ilişkili olduğunu ve hangi gözlemlerin birbirine benzediğini hızlı bir şekilde görmemizi sağlar.
# Örneğin, bir özellik diğer bir özellikle sık sık yüksek veya düşük değerlere sahipse, bu iki özellik yakın bir şekilde kümelenir. Bu, bu özellikler arasında potansiyel bir ilişkinin olduğunu gösterebilir.
#
# Bu tür görselleştirmeler genellikle veri setinin özellikleri ve gözlemleri arasındaki ilişkileri hızlı bir şekilde anlamak için kullanılır.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Seaborn Notebook</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
