# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
movies_df = pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies_df.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies_df.columns = ['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 
                     'rating', 'votes', 'revenue_millions', 'metascore']

movies_df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
movies_df.columns = [col.lower() for col in movies_df]
movies_df.columns # başlıklar kuçuk harfe döndü
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
movies_df.isnull().sum()
# Out:
# rank                  0
# genre                 0
# description           0
# director              0
# actors                0
# year                  0
# runtime               0
# rating                0
# votes                 0
# revenue_millions    128
# metascore            64
# dtype: int64

# %%
movies_df.isnull().sum().sum()
# Out:
# 192

# %%
import missingno as msno
msno.matrix(movies_df);

# %%
msno.bar(movies_df);

# %%
revenue = movies_df["revenue_millions"]
revenue.head()
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue_millions, dtype: float64

# %%
revenue_mean = revenue.mean()
revenue_mean
# Out:
# 82.95637614678897

# %%
revenue.fillna(revenue_mean,inplace=True) #fillna ile doldurduk ortalamaları aldık

# %%
revenue.isnull().sum()
# Out:
# 0

# %%
new_movies = movies_df.dropna() # metascore içindeki missing value leri düşürdük

# %%
new_movies.isnull().sum()
# Out:
# rank                0
# genre               0
# description         0
# director            0
# actors              0
# year                0
# runtime             0
# rating              0
# votes               0
# revenue_millions    0
# metascore           0
# dtype: int64

# %%
msno.matrix(new_movies); # nan degerler gitti

# %%
msno.bar(new_movies);

# %%
msno.heatmap(new_movies);
# Out:
# C:\Users\gulsah\anaconda3\lib\site-packages\seaborn\matrix.py:305: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# C:\Users\gulsah\anaconda3\lib\site-packages\seaborn\matrix.py:305: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %%
top250=new_movies.sort_values("rating", ascending= False)
top250=top250[:250]
top250.head()
# Out:
#                   rank                    genre  \
# Title
# The Dark Knight     55       Action,Crime,Drama
# Inception           81  Action,Adventure,Sci-Fi
# Interstellar        37   Adventure,Drama,Sci-Fi
# The Intouchables   250   Biography,Comedy,Drama
# Kimi no na wa       97  Animation,Drama,Fantasy
#
#                                                         description  \
# Title
# The Dark Knight   When the menace known as the Joker wreaks havo...
# Inception         A thief, who steals corporate secrets through ...
# Interstellar      A team of explorers travel through a wormhole ...
# The Intouchables  After he becomes a quadriplegic from a paragli...
# Kimi no na wa     Two strangers find themselves linked in a biza...
#
#                            director  \
# Title
# The Dark Knight   Christopher Nolan
# Inception         Christopher Nolan
# Interstellar      Christopher Nolan
# The Intouchables    Olivier Nakache
# Kimi no na wa        Makoto Shinkai
#
# ...

# %%
top250.to_csv("top250.csv")

# %%
top250.describe().T # NUMERİC OLANLAR GELİR KATEGORİC VERİLER GELMEZ
# Out:
#                   count           mean            std      min          25%  \
# rank              250.0     393.252000     276.710882     1.00     150.2500
# year              250.0    2011.932000       3.326807  2006.00    2009.0000
# runtime           250.0     123.492000      21.438104    66.00     107.0000
# rating            250.0       7.802400       0.309155     7.30       7.5000
# votes             250.0  324774.820000  258762.031454    61.00  137304.2500
# revenue_millions  250.0     116.814244     136.843242     0.01      19.2925
# metascore         250.0      73.500000      12.244907    34.00      67.0000
#
#                         50%          75%         max
# rank                 338.00     631.2500      992.00
# year                2012.00    2015.0000     2016.00
# runtime              120.50     137.0000      187.00
# rating                 7.80       8.0000        9.00
# votes             292594.50  450024.7500  1791916.00
# ...

# %%
top250=top250.sort_values("rating", ascending= False)
top250
# Out:
#                          rank                    genre  \
# Title
# The Dark Knight            55       Action,Crime,Drama
# Inception                  81  Action,Adventure,Sci-Fi
# Interstellar               37   Adventure,Drama,Sci-Fi
# The Intouchables          250   Biography,Comedy,Drama
# Kimi no na wa              97  Animation,Drama,Fantasy
# ...                       ...                      ...
# Eddie the Eagle           476   Biography,Comedy,Drama
# The Accountant             90       Action,Crime,Drama
# Jane Eyre                 833            Drama,Romance
# Avengers: Age of Ultron    95  Action,Adventure,Sci-Fi
# I Origins                 698     Drama,Romance,Sci-Fi
#
#                                                                description  \
# Title
# The Dark Knight          When the menace known as the Joker wreaks havo...
# Inception                A thief, who steals corporate secrets through ...
# ...
